# %%
# import h5py
import torch
import numpy as np
from torch.utils.data import Dataset, DataLoader, Subset
import h5py
import numpy as np

import h5py

import h5py
import numpy as np

# Load test data from test_raw.h5
with h5py.File("./data/test_psd.h5", "r") as f_test:
    X_test = f_test['data'][:]
    Y_test = f_test['labels'][:]
    S_test = f_test['sessions'][:]
    #H_test = f_test['hardwares'][:]  # Load the 'hardwares' dataset as h_test

# Load negative data from neg_raw.h5
with h5py.File("./data/neg_psd.h5", "r") as f_neg:
    X_neg = f_neg['data'][:]
    Y_neg = f_neg['labels'][:]
    S_neg = f_neg['sessions'][:]
    #H_neg = f_neg['hardwares'][:]  # Load the 'hardwares' dataset as h_neg

# Optional: Combine or use them independently depending on your requirement
# Example of concatenating them for a combined dataset
X_test = np.concatenate((X_test, X_neg), axis=0)
Y_test = np.concatenate((Y_test, Y_neg), axis=0)
S_test = np.concatenate((S_test, S_neg), axis=0)
#H_test = np.concatenate((H_test, H_neg), axis=0)

# Now, X_combined, Y_combined, S_combined, and h_combined contain the merged data


# Now, X_combined, Y_combined, and S_combined contain the merged data


# Shuffle the data
indices = np.arange(X_test.shape[0])
np.random.shuffle(indices)

# Reorder the arrays according to the shuffled indices
x_test = X_test[indices]
y_test = Y_test[indices]
s_test = S_test[indices]
#h_test = H_test[indices]


# Find unique subjects
unique_subjects = np.unique(y_test)

# Initialize lists to hold the data for x_test_e and x_test_v
x_test_e_list = []
y_test_e_list = []
s_test_e_list = []
h_test_e_list = []

x_test_v_list = []
y_test_v_list = []
s_test_v_list = []
h_test_v_list = []

# Assign the minimum session for each subject to x_test_e and the rest to x_test_v
for subject in unique_subjects:
    subject_indices = np.where(y_test == subject)[0]
    subject_sessions = s_test[subject_indices]
    
    # Skip subjects with fewer than two unique sessions
    if len(np.unique(subject_sessions)) < 2:
        continue

    print(f"Subject {subject}, Number of unique sessions: {len(np.unique(subject_sessions))}")
    
    # Assign the minimum session to the evaluation set (x_test_e)
    min_session = np.min(subject_sessions)
    
    # Append data to the evaluation set (min session)
    x_test_e_list.extend(x_test[subject_indices][subject_sessions == min_session])
    y_test_e_list.extend(y_test[subject_indices][subject_sessions == min_session])
    s_test_e_list.extend(s_test[subject_indices][subject_sessions == min_session])
    #h_test_e_list.extend(h_test[subject_indices][subject_sessions == min_session])

    # Append remaining sessions to the validation set (x_test_v)
    x_test_v_list.extend(x_test[subject_indices][subject_sessions != min_session])
    y_test_v_list.extend(y_test[subject_indices][subject_sessions != min_session])
    s_test_v_list.extend(s_test[subject_indices][subject_sessions != min_session])
    #h_test_v_list.extend(h_test[subject_indices][subject_sessions != min_session])

# Shuffle and convert lists back to numpy arrays for x_test_e
indices_e = np.arange(len(x_test_e_list))
np.random.shuffle(indices_e)

x_test_e = np.array(x_test_e_list)[indices_e]
y_test_e = np.array(y_test_e_list)[indices_e]
s_test_e = np.array(s_test_e_list)[indices_e]
#h_test_e = np.array(h_test_v_list)[indices_e]

# Shuffle and convert lists back to numpy arrays for x_test_v
indices_v = np.arange(len(x_test_v_list))
np.random.shuffle(indices_v)

x_test_v = np.array(x_test_v_list)[indices_v]
y_test_v = np.array(y_test_v_list)[indices_v]
s_test_v = np.array(s_test_v_list)[indices_v]
#h_test_v = np.array(h_test_v_list)[indices_v]
# Optional: Save the new test evaluation and validation sets to npy files (if needed)
# Out:
# Subject 70, Number of unique sessions: 19
# Subject 82, Number of unique sessions: 19
# Subject 85, Number of unique sessions: 19
# Subject 86, Number of unique sessions: 19
# Subject 96, Number of unique sessions: 18
# Subject 103, Number of unique sessions: 18
# Subject 106, Number of unique sessions: 41
# Subject 109, Number of unique sessions: 5
# Subject 111, Number of unique sessions: 19
# Subject 115, Number of unique sessions: 41
# Subject 118, Number of unique sessions: 19
# Subject 119, Number of unique sessions: 8
# Subject 125, Number of unique sessions: 19
# Subject 129, Number of unique sessions: 5
# Subject 130, Number of unique sessions: 19
# Subject 131, Number of unique sessions: 19
# Subject 136, Number of unique sessions: 19
# Subject 145, Number of unique sessions: 19
# Subject 156, Number of unique sessions: 6
# Subject 159, Number of unique sessions: 19
# Subject 167, Number of unique sessions: 2
# Subject 169, Number of unique sessions: 6
# Subject 173, Number of unique sessions: 6
# Subject 174, Number of unique sessions: 19
# Subject 175, Number of unique sessions: 6
# Subject 176, Number of unique sessions: 6
# Subject 181, Number of unique sessions: 5
# Subject 183, Number of unique sessions: 6
# Subject 184, Number of unique sessions: 19
# Subject 187, Number of unique sessions: 32
# Subject 191, Number of unique sessions: 19
# Subject 192, Number of unique sessions: 19
# Subject 194, Number of unique sessions: 19
# Subject 197, Number of unique sessions: 19
# Subject 199, Number of unique sessions: 19
# Subject 201, Number of unique sessions: 19
# Subject 203, Number of unique sessions: 6
# Subject 206, Number of unique sessions: 6
# Subject 207, Number of unique sessions: 41
# Subject 214, Number of unique sessions: 18
# Subject 216, Number of unique sessions: 6
# Subject 217, Number of unique sessions: 6
# Subject 219, Number of unique sessions: 5
# Subject 221, Number of unique sessions: 5
# Subject 225, Number of unique sessions: 6
# Subject 230, Number of unique sessions: 6
# Subject 231, Number of unique sessions: 19
# Subject 233, Number of unique sessions: 19
# Subject 236, Number of unique sessions: 42
# Subject 245, Number of unique sessions: 6
# Subject 249, Number of unique sessions: 42
# Subject 250, Number of unique sessions: 41
# Subject 251, Number of unique sessions: 41
# Subject 257, Number of unique sessions: 6
# Subject 260, Number of unique sessions: 49
# Subject 261, Number of unique sessions: 10
# Subject 262, Number of unique sessions: 6
# Subject 265, Number of unique sessions: 40
# Subject 268, Number of unique sessions: 19
# Subject 270, Number of unique sessions: 19
# Subject 277, Number of unique sessions: 13
# Subject 281, Number of unique sessions: 19
# Subject 282, Number of unique sessions: 5
# Subject 284, Number of unique sessions: 19
# Subject 286, Number of unique sessions: 19
# Subject 291, Number of unique sessions: 19
# Subject 296, Number of unique sessions: 23
# Subject 299, Number of unique sessions: 22
# Subject 301, Number of unique sessions: 23
# Subject 303, Number of unique sessions: 21
# Subject 306, Number of unique sessions: 23
# Subject 310, Number of unique sessions: 23
# Subject 314, Number of unique sessions: 6
# Subject 322, Number of unique sessions: 21
# Subject 325, Number of unique sessions: 22
# Subject 332, Number of unique sessions: 4
# Subject 336, Number of unique sessions: 23
# Subject 342, Number of unique sessions: 23
# Subject 348, Number of unique sessions: 23
# Subject 354, Number of unique sessions: 23
# Subject 357, Number of unique sessions: 22
# Subject 364, Number of unique sessions: 22
# Subject 365, Number of unique sessions: 30
# Subject 373, Number of unique sessions: 23
# Subject 374, Number of unique sessions: 20
# Subject 384, Number of unique sessions: 5
# Subject 385, Number of unique sessions: 22
# Subject 387, Number of unique sessions: 23
# Subject 402, Number of unique sessions: 9
# Subject 404, Number of unique sessions: 8
# Subject 407, Number of unique sessions: 9
# Subject 413, Number of unique sessions: 9
# Subject 414, Number of unique sessions: 9
# Subject 415, Number of unique sessions: 9
# Subject 418, Number of unique sessions: 9
# Subject 419, Number of unique sessions: 9
# Subject 422, Number of unique sessions: 8
# Subject 423, Number of unique sessions: 9
# Subject 433, Number of unique sessions: 7
# Subject 436, Number of unique sessions: 8

# %%
x_test_e.shape
# Out:
# (10000, 93, 129)

# %%
del x_test, x_test_e_list, x_test_v_list

# %%
with h5py.File("./data/neg_psd.h5", "r") as f:
    x_neg_r = f['data'][:]
    y_neg = f['labels'][:]
    s_neg = f['sessions'][:]


#X_neg_r_reshaped = X_neg_r.reshape(X_neg_r.shape[0], -1)
#X_neg_r_scaled = scaler.transform(X_neg_r_reshaped)
#X_neg_r = pca.transform(X_neg_r_scaled)

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Suppose x_test_e.shape is (N, C, L) = (100000, 93, 500)
# and x_test_v is for verification, shape (M, C, L).

############################
# Change 1: Define lists to store a separate scaler and PCA for each channel.
############################
scalers = []
pcas = []

############################
# Change 2: Create empty lists to collect the transformed PCA data 
# for x_test_e and x_test_v per channel.
############################
x_test_e_pca_list = []
x_test_v_pca_list = []
x_test_n_pca_list = []

############################
# Change 3: Iterate over each channel once, handle both x_test_e and x_test_v,
# and add progress output.
############################
num_channels = x_test_e.shape[1]

for ch in range(num_channels):
    # ---- Progress Report ----
    print(f"Processing channel {ch+1}/{num_channels}...")

    # Extract data for current channel from x_test_e and x_test_v
    channel_data_e = x_test_e[:, ch, :]  # shape (N, L)
    channel_data_v = x_test_v[:, ch, :]  # shape (M, L)
    channel_data_n = x_neg_r[:, ch, :]
    
    # 3A. Fit and transform x_test_e for this channel
    scaler_ch = StandardScaler()
    channel_data_e_scaled = scaler_ch.fit_transform(channel_data_e)
    channel_data_v_scaled = scaler_ch.transform(channel_data_v)
    channel_data_n_scaled =  scaler_ch.transform(channel_data_n)
    
    pca_ch = PCA(n_components=5)
    channel_data_e_pca = pca_ch.fit_transform(channel_data_e_scaled)
    
    
    channel_data_v_pca = pca_ch.transform(channel_data_v_scaled)
    channel_data_n_pca = pca_ch.transform(channel_data_n_scaled)
    
    # 3C. Save the scaler and PCA objects if needed later (for other data)
    #scalers.append(scaler_ch)
    #pcas.append(pca_ch)
    
    # 3D. Collect the PCA-transformed data for each channel
    x_test_e_pca_list.append(channel_data_e_pca)
    x_test_v_pca_list.append(channel_data_v_pca)
    x_test_n_pca_list.append(channel_data_n_pca)

############################
# Change 4: Stack the list back into single arrays.
# Now x_test_e has shape (N, C, 5) and x_test_v has shape (M, C, 5).
############################
x_test_e = np.stack(x_test_e_pca_list, axis=1)
x_test_v = np.stack(x_test_v_pca_list, axis=1)
x_test_n = np.stack(x_test_n_pca_list, axis=1)
############################
# Optional: Inspect explained variance ratio per channel if needed
############################
# for i, pca_ch in enumerate(pcas):
#     print(f"Channel {i}, PCA explained variance ratio: {pca_ch.explained_variance_ratio_}")

def compute_embedding_batch_two(x_test_batch, embedding_network=None):
    print(x_test_batch.shape)
    return x_test_batch
# Out:
# Processing channel 1/93...
# Processing channel 2/93...
# Processing channel 3/93...
# Processing channel 4/93...
# Processing channel 5/93...
# Processing channel 6/93...
# Processing channel 7/93...
# Processing channel 8/93...
# Processing channel 9/93...
# Processing channel 10/93...
# Processing channel 11/93...
# Processing channel 12/93...
# Processing channel 13/93...
# Processing channel 14/93...
# Processing channel 15/93...
# Processing channel 16/93...
# Processing channel 17/93...
# Processing channel 18/93...
# Processing channel 19/93...
# Processing channel 20/93...
# Processing channel 21/93...
# Processing channel 22/93...
# Processing channel 23/93...
# Processing channel 24/93...
# Processing channel 25/93...
# Processing channel 26/93...
# Processing channel 27/93...
# Processing channel 28/93...
# Processing channel 29/93...
# Processing channel 30/93...
# Processing channel 31/93...
# Processing channel 32/93...
# Processing channel 33/93...
# Processing channel 34/93...
# Processing channel 35/93...
# Processing channel 36/93...
# Processing channel 37/93...
# Processing channel 38/93...
# Processing channel 39/93...
# Processing channel 40/93...
# Processing channel 41/93...
# Processing channel 42/93...
# Processing channel 43/93...
# Processing channel 44/93...
# Processing channel 45/93...
# Processing channel 46/93...
# Processing channel 47/93...
# Processing channel 48/93...
# Processing channel 49/93...
# Processing channel 50/93...
# Processing channel 51/93...
# Processing channel 52/93...
# Processing channel 53/93...
# Processing channel 54/93...
# Processing channel 55/93...
# Processing channel 56/93...
# Processing channel 57/93...
# Processing channel 58/93...
# Processing channel 59/93...
# Processing channel 60/93...
# Processing channel 61/93...
# Processing channel 62/93...
# Processing channel 63/93...
# Processing channel 64/93...
# Processing channel 65/93...
# Processing channel 66/93...
# Processing channel 67/93...
# Processing channel 68/93...
# Processing channel 69/93...
# Processing channel 70/93...
# Processing channel 71/93...
# Processing channel 72/93...
# Processing channel 73/93...
# Processing channel 74/93...
# Processing channel 75/93...
# Processing channel 76/93...
# Processing channel 77/93...
# Processing channel 78/93...
# Processing channel 79/93...
# Processing channel 80/93...
# Processing channel 81/93...
# Processing channel 82/93...
# Processing channel 83/93...
# Processing channel 84/93...
# Processing channel 85/93...
# Processing channel 86/93...
# Processing channel 87/93...
# Processing channel 88/93...
# Processing channel 89/93...
# Processing channel 90/93...
# Processing channel 91/93...
# Processing channel 92/93...
# Processing channel 93/93...

# %%
x_test_e.shape, x_test_v.shape
# Out:
# ((10000, 93, 5), (160051, 93, 5))

# %%
channel_data_e.shape
# Out:
# (10000, 129)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from collections import defaultdict
import numpy as np
from sklearn.metrics.pairwise import euclidean_distances as ed
from sklearn.metrics.pairwise import cosine_distances as cd
from collections import defaultdict
from pyeer.eer_info import get_eer_stats
from sklearn.metrics.pairwise import manhattan_distances as md
from sklearn.metrics.pairwise import cosine_similarity as cs


def EERf(resutls):
    resutls= np.array(resutls)
    genuine  = resutls[resutls[:, 1] == 1][:, 0]
    impostor = resutls[resutls[:, 1] == 0][:, 0]
    stats_a = get_eer_stats(genuine, impostor)
    return(stats_a.eer,stats_a.fmr100)

def calculate_and_print_averages(y_train, resutls3):
    u, counts = np.unique(y_train, return_counts=True)
    eer_values = []
    ii = 0

    for i in resutls3.keys():
        re = EERf(resutls3[i])
        eer = re[0]
        print(f"{i}: EER = {re[0]:.4f}, FMR100 = {re[1]:.4f}, Count = {counts[ii]}")
        eer_values.append(eer)
        ii += 1

    average_eer = np.mean(eer_values) * 100
    std_eer = np.std(eer_values) * 100
    
    print(f"Final Average EER: {average_eer:.4f}")
    print(f"Final EER Standard Deviation: {std_eer:.4f}")
    print(f"${average_eer:.2f} \\pm {std_eer:.2f}$")

import torch.nn.functional as F


def calculate_similarity_scores_two(enrollment_embeddings, y_enrollment, verification_embeddings, y_verification,distance):
    similarity_results = []
    similarity_results_by_class = []
    similarity_results_by_class_dict = defaultdict(list)
    unique_classes = np.unique(y_enrollment)
    class_indices = [np.where(y_enrollment == cls)[0] for cls in unique_classes]
    print(verification_embeddings.shape, enrollment_embeddings.shape)
    if distance == "cd":
        similarity_matrix = -1 * cd(verification_embeddings, enrollment_embeddings)
    elif distance == "ed":
        similarity_matrix = -1 * ed(verification_embeddings, enrollment_embeddings)

    for i in range(similarity_matrix.shape[0]):
        current_class = y_verification[i]
        predicted_scores = similarity_matrix[i]
        same_class_indices = class_indices[np.where(unique_classes == current_class)[0][0]]

        for cls in unique_classes:
            same_class_indices = class_indices[np.where(unique_classes == cls)[0][0]]
            max_score = sum(sorted(predicted_scores[same_class_indices], reverse=True)[:10]) / 10
            if current_class == cls:
                similarity_results_by_class.append([max_score, 1, current_class, cls, i])
                similarity_results_by_class_dict[cls].append([max_score, 1, current_class, cls, i, cls])
            else:
                similarity_results_by_class.append([max_score, 0, current_class, cls, i])
                similarity_results_by_class_dict[cls].append([max_score, 0, current_class, cls, i, cls])

    return similarity_results_by_class, similarity_results_by_class_dict

def assessment_model_data_two(enrollment_data, ye, verification_data, yv, e_network, distance):
    x_enrollment, y_enrollment = enrollment_data, ye
    x_verification, y_verification = verification_data, yv
    enrollment_embeddings = compute_embedding_batch_two(x_enrollment, e_network)
    verification_embeddings = compute_embedding_batch_two(x_verification, e_network)
    similarity_results_by_class, similarity_results_by_class_dict = calculate_similarity_scores_two(
        enrollment_embeddings, y_enrollment, verification_embeddings, y_verification,distance
    )
    return similarity_results_by_class, similarity_results_by_class_dict

def compute_embedding_batch_two(x_test_batch, embedding_network=None):
    print(x_test_batch.shape)
    return x_test_batch

# %%
#HEREAA

# Generate a sequence of indices from 0 to the length of one of the arrays



#, s_test_b
resutls2,resutls3=assessment_model_data_two(x_test_e.reshape(x_test_e.shape[0], -1), y_test_e, x_test_v.reshape(x_test_v.shape[0], -1), y_test_v, None, distance = "ed")
#print("simple",EERf(resutls))
calculate_and_print_averages(y_test_e, resutls3)
# Out:
# (10000, 465)
# (160051, 465)
# (160051, 465) (10000, 465)
# 70: EER = 0.4572, FMR100 = 0.9483, Count = 100
# 82: EER = 0.4327, FMR100 = 0.9280, Count = 100
# 85: EER = 0.3706, FMR100 = 0.7989, Count = 100
# 86: EER = 0.3718, FMR100 = 0.8222, Count = 100
# 96: EER = 0.2985, FMR100 = 0.9771, Count = 100
# 103: EER = 0.3576, FMR100 = 0.6929, Count = 100
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# 106: EER = 0.5268, FMR100 = 0.9280, Count = 100
# 109: EER = 0.7500, FMR100 = 1.0000, Count = 100
# 111: EER = 0.6389, FMR100 = 0.9994, Count = 100
# 115: EER = 0.4832, FMR100 = 0.9185, Count = 100
# 118: EER = 0.5872, FMR100 = 0.9828, Count = 100
# 119: EER = 0.7400, FMR100 = 0.8857, Count = 100
# 125: EER = 0.2967, FMR100 = 0.7578, Count = 100
# 129: EER = 0.5803, FMR100 = 0.9675, Count = 100
# 130: EER = 0.5730, FMR100 = 0.8872, Count = 100
# 131: EER = 0.7331, FMR100 = 0.9756, Count = 100
# 136: EER = 0.3417, FMR100 = 0.8450, Count = 100
# 145: EER = 0.6717, FMR100 = 0.8872, Count = 100
# 156: EER = 0.8040, FMR100 = 0.8960, Count = 100
# 159: EER = 0.4322, FMR100 = 0.6917, Count = 100
# 167: EER = 0.6515, FMR100 = 1.0000, Count = 100
# 169: EER = 0.6060, FMR100 = 0.9700, Count = 100
# 173: EER = 0.5103, FMR100 = 0.8840, Count = 100
# 174: EER = 0.5256, FMR100 = 0.9372, Count = 100
# 175: EER = 0.8523, FMR100 = 0.9040, Count = 100
# 176: EER = 0.4980, FMR100 = 0.6820, Count = 100
# 181: EER = 0.3956, FMR100 = 1.0000, Count = 100
# 183: EER = 0.5641, FMR100 = 0.9720, Count = 100
# 184: EER = 0.7073, FMR100 = 0.9739, Count = 100
# 187: EER = 0.6194, FMR100 = 0.9829, Count = 100
# 191: EER = 0.3433, FMR100 = 0.8550, Count = 100
# 192: EER = 0.3522, FMR100 = 0.9994, Count = 100
# 194: EER = 0.6601, FMR100 = 0.9250, Count = 100
# 197: EER = 0.3502, FMR100 = 0.9267, Count = 100
# 199: EER = 0.3783, FMR100 = 0.9456, Count = 100
# 201: EER = 0.5644, FMR100 = 0.8967, Count = 100
# 203: EER = 0.3720, FMR100 = 0.4880, Count = 100
# 206: EER = 0.8025, FMR100 = 0.9720, Count = 100
# 207: EER = 0.5146, FMR100 = 0.9667, Count = 100
# 214: EER = 0.5301, FMR100 = 0.8964, Count = 100
# 216: EER = 0.3700, FMR100 = 0.7560, Count = 100
# 217: EER = 0.9043, FMR100 = 1.0000, Count = 100
# 219: EER = 0.4806, FMR100 = 0.5948, Count = 100
# 221: EER = 0.1250, FMR100 = 0.9200, Count = 100
# 225: EER = 0.8347, FMR100 = 0.9980, Count = 100
# 230: EER = 0.4960, FMR100 = 0.8640, Count = 100
# 231: EER = 0.6133, FMR100 = 0.9811, Count = 100
# 233: EER = 0.6672, FMR100 = 0.9911, Count = 100
# 236: EER = 0.5910, FMR100 = 0.9802, Count = 100
# 245: EER = 0.4040, FMR100 = 0.8580, Count = 100
# 249: EER = 0.5198, FMR100 = 0.9517, Count = 100
# 250: EER = 0.4915, FMR100 = 0.9742, Count = 100
# 251: EER = 0.5577, FMR100 = 0.9335, Count = 100
# 257: EER = 0.2269, FMR100 = 1.0000, Count = 100
# 260: EER = 0.3846, FMR100 = 0.8769, Count = 100
# 261: EER = 0.4022, FMR100 = 0.9789, Count = 100
# 262: EER = 0.3460, FMR100 = 0.5600, Count = 100
# 265: EER = 0.2631, FMR100 = 0.9390, Count = 100
# 268: EER = 0.3694, FMR100 = 0.9467, Count = 100
# 270: EER = 0.4768, FMR100 = 0.9750, Count = 100
# 277: EER = 0.2778, FMR100 = 0.8942, Count = 100
# 281: EER = 0.3567, FMR100 = 0.8989, Count = 100
# 282: EER = 0.3432, FMR100 = 0.9250, Count = 100
# 284: EER = 0.3528, FMR100 = 0.9378, Count = 100
# 286: EER = 0.3939, FMR100 = 0.9006, Count = 100
# 291: EER = 0.3917, FMR100 = 0.9889, Count = 100
# 296: EER = 0.5060, FMR100 = 1.0000, Count = 100
# 299: EER = 0.3987, FMR100 = 0.9624, Count = 100
# 301: EER = 0.3792, FMR100 = 0.9377, Count = 100
# 303: EER = 0.5760, FMR100 = 0.8500, Count = 100
# 306: EER = 0.3968, FMR100 = 0.8682, Count = 100
# 310: EER = 0.5668, FMR100 = 0.9373, Count = 100
# 314: EER = 0.4000, FMR100 = 0.7540, Count = 100
# 322: EER = 0.5375, FMR100 = 0.8905, Count = 100
# 325: EER = 0.4320, FMR100 = 0.8110, Count = 100
# 332: EER = 0.5650, FMR100 = 1.0000, Count = 100
# 336: EER = 0.4191, FMR100 = 0.9882, Count = 100
# 342: EER = 0.2291, FMR100 = 0.7973, Count = 100
# 348: EER = 0.3873, FMR100 = 0.9259, Count = 100
# 354: EER = 0.3564, FMR100 = 0.9768, Count = 100
# 357: EER = 0.2519, FMR100 = 0.8352, Count = 100
# 364: EER = 0.2858, FMR100 = 0.9314, Count = 100
# 365: EER = 0.3121, FMR100 = 0.9410, Count = 100
# 373: EER = 0.3436, FMR100 = 0.9745, Count = 100
# 374: EER = 0.2900, FMR100 = 0.9642, Count = 100
# 384: EER = 0.2575, FMR100 = 0.9150, Count = 100
# 385: EER = 0.3676, FMR100 = 0.8714, Count = 100
# 387: EER = 0.5761, FMR100 = 1.0000, Count = 100
# 402: EER = 0.3865, FMR100 = 0.8375, Count = 100
# 404: EER = 0.1600, FMR100 = 0.5657, Count = 100
# 407: EER = 0.6154, FMR100 = 0.9912, Count = 100
# 413: EER = 0.4087, FMR100 = 0.9300, Count = 100
# 414: EER = 0.2000, FMR100 = 0.6025, Count = 100
# 415: EER = 0.1937, FMR100 = 0.9513, Count = 100
# 418: EER = 0.2850, FMR100 = 0.9150, Count = 100
# 419: EER = 0.2742, FMR100 = 0.9237, Count = 100
# 422: EER = 0.1192, FMR100 = 0.7229, Count = 100
# 423: EER = 0.2575, FMR100 = 0.9050, Count = 100
# 433: EER = 0.3217, FMR100 = 0.6833, Count = 100
# 436: EER = 0.2600, FMR100 = 0.7271, Count = 100
# Final Average EER: 45.2016
# Final EER Standard Deviation: 16.6060
# $45.20 \pm 16.61$

# %%
#HEREAA

# Generate a sequence of indices from 0 to the length of one of the arrays



#, s_test_b
resutls2,resutls3=assessment_model_data_two(x_test_e.reshape(x_test_e.shape[0], -1), y_test_e, x_test_v.reshape(x_test_v.shape[0], -1), y_test_v, None, distance = "cd")
#print("simple",EERf(resutls))
calculate_and_print_averages(y_test_e, resutls3)
# Out:
# (10000, 465)
# (160051, 465)
# (160051, 465) (10000, 465)
# 70: EER = 0.4594, FMR100 = 0.9578, Count = 100
# 82: EER = 0.4350, FMR100 = 0.9543, Count = 100
# 85: EER = 0.3734, FMR100 = 0.8167, Count = 100
# 86: EER = 0.3722, FMR100 = 0.8244, Count = 100
# 96: EER = 0.4506, FMR100 = 0.9800, Count = 100
# 103: EER = 0.3588, FMR100 = 0.8012, Count = 100
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# 106: EER = 0.5296, FMR100 = 0.9202, Count = 100
# 109: EER = 0.7500, FMR100 = 1.0000, Count = 100
# 111: EER = 0.6379, FMR100 = 0.9956, Count = 100
# 115: EER = 0.4886, FMR100 = 0.9124, Count = 100
# 118: EER = 0.6463, FMR100 = 0.9711, Count = 100
# 119: EER = 0.7400, FMR100 = 0.9029, Count = 100
# 125: EER = 0.3005, FMR100 = 0.7294, Count = 100
# 129: EER = 0.5835, FMR100 = 0.9725, Count = 100
# 130: EER = 0.5767, FMR100 = 0.8956, Count = 100
# 131: EER = 0.7333, FMR100 = 0.9733, Count = 100
# 136: EER = 0.3436, FMR100 = 0.8956, Count = 100
# 145: EER = 0.6717, FMR100 = 0.9189, Count = 100
# 156: EER = 0.8040, FMR100 = 0.9100, Count = 100
# 159: EER = 0.4357, FMR100 = 0.6944, Count = 100
# 167: EER = 0.6522, FMR100 = 1.0000, Count = 100
# 169: EER = 0.6083, FMR100 = 0.9680, Count = 100
# 173: EER = 0.5140, FMR100 = 0.8820, Count = 100
# 174: EER = 0.5285, FMR100 = 0.9550, Count = 100
# 175: EER = 0.5980, FMR100 = 0.6660, Count = 100
# 176: EER = 0.3500, FMR100 = 0.7560, Count = 100
# 181: EER = 0.4151, FMR100 = 1.0000, Count = 100
# 183: EER = 0.5648, FMR100 = 0.9760, Count = 100
# 184: EER = 0.7150, FMR100 = 0.9844, Count = 100
# 187: EER = 0.6245, FMR100 = 0.9877, Count = 100
# 191: EER = 0.3457, FMR100 = 0.8461, Count = 100
# 192: EER = 0.4328, FMR100 = 0.9894, Count = 100
# 194: EER = 0.6629, FMR100 = 0.9283, Count = 100
# 197: EER = 0.3489, FMR100 = 0.9300, Count = 100
# 199: EER = 0.3700, FMR100 = 0.9556, Count = 100
# 201: EER = 0.5662, FMR100 = 0.9333, Count = 100
# 203: EER = 0.4360, FMR100 = 0.5740, Count = 100
# 206: EER = 0.7600, FMR100 = 0.8620, Count = 100
# 207: EER = 0.5174, FMR100 = 0.9695, Count = 100
# 214: EER = 0.5332, FMR100 = 0.9017, Count = 100
# 216: EER = 0.3686, FMR100 = 0.7760, Count = 100
# 217: EER = 0.9040, FMR100 = 1.0000, Count = 100
# 219: EER = 0.5323, FMR100 = 0.6185, Count = 100
# 221: EER = 0.1500, FMR100 = 0.9650, Count = 100
# 225: EER = 0.8360, FMR100 = 1.0000, Count = 100
# 230: EER = 0.4940, FMR100 = 0.9200, Count = 100
# 231: EER = 0.6141, FMR100 = 0.9867, Count = 100
# 233: EER = 0.6661, FMR100 = 0.9939, Count = 100
# 236: EER = 0.5917, FMR100 = 0.9883, Count = 100
# 245: EER = 0.4024, FMR100 = 0.8700, Count = 100
# 249: EER = 0.5203, FMR100 = 0.9571, Count = 100
# 250: EER = 0.4908, FMR100 = 0.9812, Count = 100
# 251: EER = 0.5592, FMR100 = 0.9453, Count = 100
# 257: EER = 0.4240, FMR100 = 0.9980, Count = 100
# 260: EER = 0.3871, FMR100 = 0.8458, Count = 100
# 261: EER = 0.4027, FMR100 = 0.9789, Count = 100
# 262: EER = 0.3560, FMR100 = 0.5900, Count = 100
# 265: EER = 0.2318, FMR100 = 0.9369, Count = 100
# 268: EER = 0.3733, FMR100 = 0.9683, Count = 100
# 270: EER = 0.5342, FMR100 = 0.9633, Count = 100
# 277: EER = 0.2836, FMR100 = 0.9208, Count = 100
# 281: EER = 0.3612, FMR100 = 0.9017, Count = 100
# 282: EER = 0.3476, FMR100 = 0.9475, Count = 100
# 284: EER = 0.3579, FMR100 = 0.9572, Count = 100
# 286: EER = 0.3994, FMR100 = 0.9400, Count = 100
# 291: EER = 0.3872, FMR100 = 0.9994, Count = 100
# 296: EER = 0.5077, FMR100 = 1.0000, Count = 100
# 299: EER = 0.4009, FMR100 = 0.9752, Count = 100
# 301: EER = 0.3709, FMR100 = 0.9809, Count = 100
# 303: EER = 0.5800, FMR100 = 0.9055, Count = 100
# 306: EER = 0.4374, FMR100 = 0.8673, Count = 100
# 310: EER = 0.5714, FMR100 = 0.9405, Count = 100
# 314: EER = 0.4160, FMR100 = 0.8120, Count = 100
# 322: EER = 0.5395, FMR100 = 0.8940, Count = 100
# 325: EER = 0.4367, FMR100 = 0.8371, Count = 100
# 332: EER = 0.5708, FMR100 = 1.0000, Count = 100
# 336: EER = 0.4346, FMR100 = 0.9877, Count = 100
# 342: EER = 0.2505, FMR100 = 0.7991, Count = 100
# 348: EER = 0.4009, FMR100 = 0.9268, Count = 100
# 354: EER = 0.3800, FMR100 = 0.9782, Count = 100
# 357: EER = 0.2676, FMR100 = 0.8576, Count = 100
# 364: EER = 0.3067, FMR100 = 0.9357, Count = 100
# 365: EER = 0.3284, FMR100 = 0.9424, Count = 100
# 373: EER = 0.3659, FMR100 = 0.9736, Count = 100
# 374: EER = 0.3065, FMR100 = 0.9647, Count = 100
# 384: EER = 0.2731, FMR100 = 0.9125, Count = 100
# 385: EER = 0.3859, FMR100 = 0.8729, Count = 100
# 387: EER = 0.5929, FMR100 = 1.0000, Count = 100
# 402: EER = 0.3937, FMR100 = 0.8387, Count = 100
# 404: EER = 0.1690, FMR100 = 0.5829, Count = 100
# 407: EER = 0.6237, FMR100 = 0.9912, Count = 100
# 413: EER = 0.4251, FMR100 = 0.9287, Count = 100
# 414: EER = 0.2075, FMR100 = 0.6262, Count = 100
# 415: EER = 0.2162, FMR100 = 0.9513, Count = 100
# 418: EER = 0.3092, FMR100 = 0.9163, Count = 100
# 419: EER = 0.2978, FMR100 = 0.9237, Count = 100
# 422: EER = 0.1333, FMR100 = 0.7214, Count = 100
# 423: EER = 0.2800, FMR100 = 0.9100, Count = 100
# 433: EER = 0.3367, FMR100 = 0.6800, Count = 100
# 436: EER = 0.2700, FMR100 = 0.7286, Count = 100
# Final Average EER: 45.9969
# Final EER Standard Deviation: 15.5870
# $46.00 \pm 15.59$

# %%
# Flatten each array from 3D to 2D
x_test_e = x_test_e.reshape(x_test_e.shape[0], -1)
x_test_v= x_test_v.reshape(x_test_v.shape[0], -1)
x_test_n = x_test_n.reshape(x_test_n.shape[0], -1)

# %%
#from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.decomposition import IncrementalPCA
from sklearn.pipeline import Pipeline
from sklearn.utils import shuffle
from sklearn.kernel_approximation import RBFSampler
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.utils import shuffle


def classifiers_learn(enrollment_data, ye, verification_data, yv, e_network, negative_raw):
    """
    Learn classifiers per unique subject and evaluate using EER.
    """
    x_enrollment, y_enrollment = enrollment_data, ye
    x_verification, y_verification = verification_data, yv
    
    # Compute embeddings
    enrollment_embeddings = compute_embedding_batch_two(x_enrollment, e_network)
    verification_embeddings = compute_embedding_batch_two(x_verification, e_network)
    negative_embeddings = compute_embedding_batch_two(negative_raw, e_network)
    
    unique_classes = np.unique(y_enrollment)
    results = {}

    print("Unique classes: ", unique_classes)

    for cls in unique_classes:
        # Prepare training data
        positive_indices = np.where(y_enrollment == cls)[0]
        negative_indices = np.arange(len(negative_embeddings))
        
        train_embeddings = np.concatenate([enrollment_embeddings[positive_indices], negative_embeddings])
        train_labels = np.concatenate([np.ones(len(positive_indices)), np.zeros(len(negative_indices))])

        # Prepare testing data
        test_embeddings = verification_embeddings
        test_labels =(y_verification == cls).astype(int)


        # Initialize Incremental PCA
        #pca = IncrementalPCA(n_components=50)  # Retain 80% of variance or specify a fixed number of components
        

        #batch_size = 5000  # Define batch size
        #for i in range(0, train_embeddings.shape[0], batch_size):
            #batch = train_embeddings[i:i + batch_size]
            #pca.partial_fit(batch)  
        #train_embeddings_reduced = pca.transform(train_embeddings)
        #print("Reduced Training Shape:", train_embeddings_reduced.shape)
        #test_embeddings_reduced = pca.transform(test_embeddings)
        #print("Reduced Test Shape:", test_embeddings_reduced.shape)

        # Train Random Forest model
        #rf_model = RandomForestClassifier(random_state=42, class_weight='balanced', n_jobs=-1)
        #rf_model.fit(train_embeddings, train_labels)
        #rf_probabilities = rf_model.predict_proba(test_embeddings)[:, 1]  # Use probabilities for EER calculation

        
        # Replace RandomForest with Linear SVM + Kernel Approximation
        pipeline = Pipeline([
            #('scaler', StandardScaler()),
            ('kernel_approximation', RBFSampler(gamma=1, random_state=42, n_components=500)),  # Approximate RBF kernel
            ('classifier', SGDClassifier(loss='hinge', max_iter=1000, tol=1e-3, class_weight='balanced', random_state=42, n_jobs=20))
        ])
        
        # Shuffle and split the data
        X, y = shuffle(train_embeddings, train_labels, random_state=42)
        
        # Train the pipeline
        pipeline.fit(X, y)
        
        # Predict probabilities for the test set
        # Note: SGDClassifier doesn't provide probabilities directly, so we use decision_function
        decision_scores = pipeline.decision_function(test_embeddings)
        probabilities = 1 / (1 + np.exp(-decision_scores))  # Sigmoid function to map decision scores to probabilities
        
        # Calculate EER
        svm_eer = calculate_eer(test_labels, probabilities)
        
        print(f"Class {cls}: Linear SVM with Kernel Approximation EER = {svm_eer:.4f}")
        
        results[cls] = {
            'RandomForest': {'EER': svm_eer}
        }
        
    return results

# %%
# Test your pipeline with synthetic data



resutls = classifiers_learn(
    x_test_e, y_test_e, x_test_v, y_test_v, None, x_test_n
)
# Print results
#print("EER:", EERf(resutls))

calculate_mean_std(resutls)
# Out:
# (10000, 465)
# (160051, 465)
# (84408, 465)
# Unique classes:  [ 70  82  85  86  96 103 106 109 111 115 118 119 125 129 130 131 136 145
#  156 159 167 169 173 174 175 176 181 183 184 187 191 192 194 197 199 201
#  203 206 207 214 216 217 219 221 225 230 231 233 236 245 249 250 251 257
#  260 261 262 265 268 270 277 281 282 284 286 291 296 299 301 303 306 310
#  314 322 325 332 336 342 348 354 357 364 365 373 374 384 385 387 402 404
#  407 413 414 415 418 419 422 423 433 436]
# genuine_scores:  1800 0.3560941388198902 impostor_scores 158251 0.2110182846336971
# Class 70: Linear SVM with Kernel Approximation EER = 0.3406
# genuine_scores:  1708 0.31463721818158297 impostor_scores 158343 0.2170056717591539
# Class 82: Linear SVM with Kernel Approximation EER = 0.3981
# genuine_scores:  1800 0.2499799282582374 impostor_scores 158251 0.10576909764460228
# Class 85: Linear SVM with Kernel Approximation EER = 0.3311
# genuine_scores:  1800 0.3244500114449 impostor_scores 158251 0.2093627494568866
# Class 86: Linear SVM with Kernel Approximation EER = 0.3422
# genuine_scores:  1700 0.0406327706235116 impostor_scores 158351 0.042685638869852736
# Class 96: Linear SVM with Kernel Approximation EER = 0.4185
# genuine_scores:  1700 0.4406306347244714 impostor_scores 158351 0.28583202177929046
# Class 103: Linear SVM with Kernel Approximation EER = 0.3201
# genuine_scores:  4100 0.46505835401586676 impostor_scores 155951 0.31529566025785205
# Class 106: Linear SVM with Kernel Approximation EER = 0.4595
# genuine_scores:  400 0.09439356863629575 impostor_scores 159651 0.2316905233870619
# Class 109: Linear SVM with Kernel Approximation EER = 0.7500
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# genuine_scores:  1800 0.04028342848889149 impostor_scores 158251 0.016486082202560357
# Class 111: Linear SVM with Kernel Approximation EER = 0.3706
# genuine_scores:  4100 0.2992550886531256 impostor_scores 155951 0.14289313980483137
# Class 115: Linear SVM with Kernel Approximation EER = 0.4059
# genuine_scores:  1800 0.11744254704408102 impostor_scores 158251 0.08691783100443118
# Class 118: Linear SVM with Kernel Approximation EER = 0.4572
# genuine_scores:  700 0.11002404459676272 impostor_scores 159351 0.06685307196016
# Class 119: Linear SVM with Kernel Approximation EER = 0.6471
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# genuine_scores:  1800 0.3400255184534558 impostor_scores 158251 0.1392627675090281
# Class 125: Linear SVM with Kernel Approximation EER = 0.2206
# genuine_scores:  400 0.22635357771730721 impostor_scores 159651 0.12336769039953716
# Class 129: Linear SVM with Kernel Approximation EER = 0.3850
# genuine_scores:  1800 0.36867841326611456 impostor_scores 158251 0.09789722945307422
# Class 130: Linear SVM with Kernel Approximation EER = 0.3261
# genuine_scores:  1800 0.19660335201951798 impostor_scores 158251 0.15280386877123323
# Class 131: Linear SVM with Kernel Approximation EER = 0.5807
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# genuine_scores:  1800 0.2195628638566453 impostor_scores 158251 0.09864036987027235
# Class 136: Linear SVM with Kernel Approximation EER = 0.2772
# genuine_scores:  1800 0.14370681346881625 impostor_scores 158251 0.11605775033434716
# Class 145: Linear SVM with Kernel Approximation EER = 0.6511
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# genuine_scores:  500 0.15149049704177664 impostor_scores 159551 0.1485510250541005
# Class 156: Linear SVM with Kernel Approximation EER = 0.7800
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# genuine_scores:  1800 0.26086680058760475 impostor_scores 158251 0.031984107832304494
# Class 159: Linear SVM with Kernel Approximation EER = 0.3022
# genuine_scores:  100 0.2001603040740193 impostor_scores 159951 0.17056610565743047
# Class 167: Linear SVM with Kernel Approximation EER = 0.4500
# genuine_scores:  500 0.49036120125780264 impostor_scores 159551 0.5544735201631437
# Class 169: Linear SVM with Kernel Approximation EER = 0.4840
# genuine_scores:  500 0.5757233691484581 impostor_scores 159551 0.10157128708812974
# Class 173: Linear SVM with Kernel Approximation EER = 0.2660
# genuine_scores:  1800 0.20316065479505935 impostor_scores 158251 0.1557958827754461
# Class 174: Linear SVM with Kernel Approximation EER = 0.4333
# genuine_scores:  500 0.3823041096210364 impostor_scores 159551 0.12697227333348762
# Class 175: Linear SVM with Kernel Approximation EER = 0.1702
# genuine_scores:  500 0.2819113553059781 impostor_scores 159551 0.06766777576612633
# Class 176: Linear SVM with Kernel Approximation EER = 0.2080
# genuine_scores:  400 0.010013074577943175 impostor_scores 159651 0.048695083494187205
# Class 181: Linear SVM with Kernel Approximation EER = 0.4933
# genuine_scores:  500 0.5323900149636157 impostor_scores 159551 0.14518796724329003
# Class 183: Linear SVM with Kernel Approximation EER = 0.3040
# genuine_scores:  1800 0.21493464811289165 impostor_scores 158251 0.0716314635956998
# Class 184: Linear SVM with Kernel Approximation EER = 0.4622
# genuine_scores:  3100 0.18642637535194756 impostor_scores 156951 0.14215295572427608
# Class 187: Linear SVM with Kernel Approximation EER = 0.4177
# genuine_scores:  1800 0.26873676491472703 impostor_scores 158251 0.14221314285151312
# Class 191: Linear SVM with Kernel Approximation EER = 0.2733
# genuine_scores:  1800 0.11634525746514904 impostor_scores 158251 0.0845561708506296
# Class 192: Linear SVM with Kernel Approximation EER = 0.4939
# genuine_scores:  1800 0.13904501345295814 impostor_scores 158251 0.12148149991780474
# Class 194: Linear SVM with Kernel Approximation EER = 0.5933
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# genuine_scores:  1800 0.5469820123899066 impostor_scores 158251 0.3461713642677744
# Class 197: Linear SVM with Kernel Approximation EER = 0.3594
# genuine_scores:  1800 0.429610255579091 impostor_scores 158251 0.2513758344862588
# Class 199: Linear SVM with Kernel Approximation EER = 0.3480
# genuine_scores:  1800 0.27898019605723595 impostor_scores 158251 0.039896407454812086
# Class 201: Linear SVM with Kernel Approximation EER = 0.3972
# genuine_scores:  500 0.2140460550089505 impostor_scores 159551 0.06969874928986779
# Class 203: Linear SVM with Kernel Approximation EER = 0.1720
# genuine_scores:  500 0.20475442160228047 impostor_scores 159551 0.037071324573417795
# Class 206: Linear SVM with Kernel Approximation EER = 0.2367
# genuine_scores:  4000 0.41632596387351634 impostor_scores 156051 0.33799047391026604
# Class 207: Linear SVM with Kernel Approximation EER = 0.4963
# genuine_scores:  1679 0.24004249328230448 impostor_scores 158372 0.11968099321276189
# Class 214: Linear SVM with Kernel Approximation EER = 0.3836
# genuine_scores:  500 0.3486822466557033 impostor_scores 159551 0.1576017618420762
# Class 216: Linear SVM with Kernel Approximation EER = 0.3520
# genuine_scores:  500 0.1680412106261643 impostor_scores 159551 0.13291820150914482
# Class 217: Linear SVM with Kernel Approximation EER = 0.5800
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# genuine_scores:  464 0.14037816017731258 impostor_scores 159587 0.04783260079818135
# Class 219: Linear SVM with Kernel Approximation EER = 0.2394
# genuine_scores:  400 0.006307999401617426 impostor_scores 159651 0.022794345018751924
# Class 221: Linear SVM with Kernel Approximation EER = 0.4680
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# genuine_scores:  500 0.06382156323459029 impostor_scores 159551 0.021005161985638135
# Class 225: Linear SVM with Kernel Approximation EER = 0.3540
# genuine_scores:  500 0.26263490732389416 impostor_scores 159551 0.18988431308252407
# Class 230: Linear SVM with Kernel Approximation EER = 0.4807
# genuine_scores:  1800 0.3075180663955601 impostor_scores 158251 0.21239294638420858
# Class 231: Linear SVM with Kernel Approximation EER = 0.5517
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# genuine_scores:  1800 0.2861461050652897 impostor_scores 158251 0.30257696432554015
# Class 233: Linear SVM with Kernel Approximation EER = 0.6100
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# genuine_scores:  4100 0.2556238345527171 impostor_scores 155951 0.223504255833839
# Class 236: Linear SVM with Kernel Approximation EER = 0.5174
# genuine_scores:  500 0.5223664896449357 impostor_scores 159551 0.14854613031383027
# Class 245: Linear SVM with Kernel Approximation EER = 0.0926
# genuine_scores:  4100 0.4793648720249223 impostor_scores 155951 0.3773656311257296
# Class 249: Linear SVM with Kernel Approximation EER = 0.4322
# genuine_scores:  4000 0.3318546139348742 impostor_scores 156051 0.18026229668680244
# Class 250: Linear SVM with Kernel Approximation EER = 0.3892
# genuine_scores:  4000 0.22354565260380196 impostor_scores 156051 0.0581571683541931
# Class 251: Linear SVM with Kernel Approximation EER = 0.3372
# genuine_scores:  500 0.012019577488715091 impostor_scores 159551 0.05682821030344225
# Class 257: Linear SVM with Kernel Approximation EER = 0.5700
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# genuine_scores:  4800 0.42804651394722376 impostor_scores 155251 0.32641617181062377
# Class 260: Linear SVM with Kernel Approximation EER = 0.3635
# genuine_scores:  900 0.1397740678298178 impostor_scores 159151 0.09216016401606739
# Class 261: Linear SVM with Kernel Approximation EER = 0.3771
# genuine_scores:  500 0.6506311171478741 impostor_scores 159551 0.1563988189986353
# Class 262: Linear SVM with Kernel Approximation EER = 0.0565
# genuine_scores:  3900 0.057963799921776867 impostor_scores 156151 0.016502288986906345
# Class 265: Linear SVM with Kernel Approximation EER = 0.5718
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# genuine_scores:  1800 0.6682264336459446 impostor_scores 158251 0.29723878115955543
# Class 268: Linear SVM with Kernel Approximation EER = 0.2362
# genuine_scores:  1800 0.030522271621709056 impostor_scores 158251 0.04478556282599893
# Class 270: Linear SVM with Kernel Approximation EER = 0.5111
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# genuine_scores:  1200 0.6152176369753382 impostor_scores 158851 0.34407922097179067
# Class 277: Linear SVM with Kernel Approximation EER = 0.3001
# genuine_scores:  1800 0.2634042259329014 impostor_scores 158251 0.10380481490508109
# Class 281: Linear SVM with Kernel Approximation EER = 0.2839
# genuine_scores:  400 0.41822325432805074 impostor_scores 159651 0.07549242214222825
# Class 282: Linear SVM with Kernel Approximation EER = 0.2460
# genuine_scores:  1800 0.2078924738135673 impostor_scores 158251 0.09610780839074741
# Class 284: Linear SVM with Kernel Approximation EER = 0.2858
# genuine_scores:  1800 0.637283616223648 impostor_scores 158251 0.19187403241356077
# Class 286: Linear SVM with Kernel Approximation EER = 0.0939
# genuine_scores:  1800 0.3502127906758593 impostor_scores 158251 0.2029231785261512
# Class 291: Linear SVM with Kernel Approximation EER = 0.3406
# genuine_scores:  2200 0.08746080827039655 impostor_scores 157851 0.09360283121190029
# Class 296: Linear SVM with Kernel Approximation EER = 0.4959
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# genuine_scores:  2100 0.43537065812683257 impostor_scores 157951 0.17380117969201728
# Class 299: Linear SVM with Kernel Approximation EER = 0.2176
# genuine_scores:  2200 0.824220141640279 impostor_scores 157851 0.38718085590525964
# Class 301: Linear SVM with Kernel Approximation EER = 0.1196
# genuine_scores:  2000 0.4574091310501746 impostor_scores 158051 0.10475996421167379
# Class 303: Linear SVM with Kernel Approximation EER = 0.2345
# genuine_scores:  2200 0.09743422197919269 impostor_scores 157851 0.015515347900990224
# Class 306: Linear SVM with Kernel Approximation EER = 0.3805
# genuine_scores:  2200 0.14631614630926018 impostor_scores 157851 0.09629399184665903
# Class 310: Linear SVM with Kernel Approximation EER = 0.3855
# genuine_scores:  500 0.6349598643786538 impostor_scores 159551 0.35560160251962775
# Class 314: Linear SVM with Kernel Approximation EER = 0.2160
# genuine_scores:  2000 0.3195282692831757 impostor_scores 158051 0.10913347564763883
# Class 322: Linear SVM with Kernel Approximation EER = 0.2290
# genuine_scores:  2100 0.36026578732234094 impostor_scores 157951 0.05547160501811877
# Class 325: Linear SVM with Kernel Approximation EER = 0.1048
# genuine_scores:  300 0.10705410422485563 impostor_scores 159751 0.12195769076799617
# Class 332: Linear SVM with Kernel Approximation EER = 0.5533
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# genuine_scores:  2200 0.3066842503383784 impostor_scores 157851 0.10712040531335604
# Class 336: Linear SVM with Kernel Approximation EER = 0.1729
# genuine_scores:  2200 0.7416100347912764 impostor_scores 157851 0.19577174932627872
# Class 342: Linear SVM with Kernel Approximation EER = 0.0823
# genuine_scores:  2200 0.3309984668315354 impostor_scores 157851 0.1027304310380394
# Class 348: Linear SVM with Kernel Approximation EER = 0.1977
# genuine_scores:  2200 0.4670673143140736 impostor_scores 157851 0.1001270074161572
# Class 354: Linear SVM with Kernel Approximation EER = 0.1347
# genuine_scores:  2100 0.20660456039568162 impostor_scores 157951 0.08764691856146628
# Class 357: Linear SVM with Kernel Approximation EER = 0.1952
# genuine_scores:  2100 0.49717253128536437 impostor_scores 157951 0.1708239212234768
# Class 364: Linear SVM with Kernel Approximation EER = 0.2129
# genuine_scores:  2900 0.3809442150447414 impostor_scores 157151 0.1219680258028375
# Class 365: Linear SVM with Kernel Approximation EER = 0.1933
# genuine_scores:  2200 0.3720006581873634 impostor_scores 157851 0.08579815276921829
# Class 373: Linear SVM with Kernel Approximation EER = 0.1786
# genuine_scores:  1900 0.5034684607865724 impostor_scores 158151 0.1376305645201178
# Class 374: Linear SVM with Kernel Approximation EER = 0.1768
# genuine_scores:  400 0.7220713103942349 impostor_scores 159651 0.21045992484051051
# Class 384: Linear SVM with Kernel Approximation EER = 0.1275
# genuine_scores:  2100 0.5658557972886106 impostor_scores 157951 0.13371162537623338
# Class 385: Linear SVM with Kernel Approximation EER = 0.1143
# genuine_scores:  2200 0.3147515345109329 impostor_scores 157851 0.10951435208924355
# Class 387: Linear SVM with Kernel Approximation EER = 0.3409
# genuine_scores:  800 0.5445093837811729 impostor_scores 159251 0.2387226881325503
# Class 402: Linear SVM with Kernel Approximation EER = 0.2850
# genuine_scores:  700 0.31238192620983163 impostor_scores 159351 0.0808760040746874
# Class 404: Linear SVM with Kernel Approximation EER = 0.1100
# genuine_scores:  800 0.39801558975786555 impostor_scores 159251 0.2659501314440738
# Class 407: Linear SVM with Kernel Approximation EER = 0.4462
# genuine_scores:  800 0.5064236594723238 impostor_scores 159251 0.20532254458506444
# Class 413: Linear SVM with Kernel Approximation EER = 0.2704
# genuine_scores:  800 0.19545470487260577 impostor_scores 159251 0.05459430939088618
# Class 414: Linear SVM with Kernel Approximation EER = 0.0938
# genuine_scores:  800 0.6594336081816631 impostor_scores 159251 0.11996624621782116
# Class 415: Linear SVM with Kernel Approximation EER = 0.0363
# genuine_scores:  800 0.5309734196345981 impostor_scores 159251 0.11257520003469045
# Class 418: Linear SVM with Kernel Approximation EER = 0.1103
# genuine_scores:  800 0.86870053391482 impostor_scores 159251 0.38254373746121295
# Class 419: Linear SVM with Kernel Approximation EER = 0.1412
# genuine_scores:  700 0.602628335506095 impostor_scores 159351 0.11882352509872895
# Class 422: Linear SVM with Kernel Approximation EER = 0.0876
# genuine_scores:  800 0.7751316989447988 impostor_scores 159251 0.2834956468014126
# Class 423: Linear SVM with Kernel Approximation EER = 0.1829
# genuine_scores:  600 0.27722866812584784 impostor_scores 159451 0.06553066963317553
# Class 433: Linear SVM with Kernel Approximation EER = 0.1683
# genuine_scores:  700 0.7979632916641448 impostor_scores 159351 0.279502613606962
# Class 436: Linear SVM with Kernel Approximation EER = 0.1414
# Final Average EER RandomForest: 32.9844
# Final EER Standard Deviation RandomForest: 16.3324
# $32.98 \pm 16.33$
# {'RandomForest': {'mean': 32.984375012463815, 'std': 16.332370218064835}}

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.decomposition import IncrementalPCA
from sklearn.pipeline import Pipeline
from sklearn.utils import shuffle
from sklearn.kernel_approximation import RBFSampler
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.utils import shuffle


def calculate_eer(y_true, y_scores):
    """
    Calculate the Equal Error Rate (EER) and FMR100 using pyeer.
    """
    # Separate genuine and impostor scores
    genuine_scores = y_scores[y_true == 1]
    impostor_scores = y_scores[y_true == 0]
    #print(y_true, y_scores)

    #print(genuine_scores, impostor_scores)
    print("genuine_scores: ", len(genuine_scores), sum(genuine_scores)/len(genuine_scores), "impostor_scores", len(impostor_scores), sum(impostor_scores)/len(impostor_scores))
    
    # Use pyeer to compute EER stats
    stats = get_eer_stats(genuine_scores, impostor_scores)
    
    return stats.eer

def classifiers_learn(enrollment_data, ye, verification_data, yv, e_network, negative_raw):
    """
    Learn classifiers per unique subject and evaluate using EER.
    """
    x_enrollment, y_enrollment = enrollment_data, ye
    x_verification, y_verification = verification_data, yv
    
    # Compute embeddings
    enrollment_embeddings = compute_embedding_batch_two(x_enrollment, e_network)
    verification_embeddings = compute_embedding_batch_two(x_verification, e_network)
    negative_embeddings = compute_embedding_batch_two(negative_raw, e_network)
    
    unique_classes = np.unique(y_enrollment)
    results = {}

    print("Unique classes: ", unique_classes)

    for cls in unique_classes:
        # Prepare training data
        positive_indices = np.where(y_enrollment == cls)[0]
        negative_indices = np.arange(len(negative_embeddings))
        
        train_embeddings = np.concatenate([enrollment_embeddings[positive_indices], negative_embeddings])
        train_labels = np.concatenate([np.ones(len(positive_indices)), np.zeros(len(negative_indices))])

        # Prepare testing data
        test_embeddings = verification_embeddings
        test_labels =(y_verification == cls).astype(int)


        # Initialize Incremental PCA
        #pca = IncrementalPCA(n_components=50)  # Retain 80% of variance or specify a fixed number of components
        

        #batch_size = 5000  # Define batch size
        #for i in range(0, train_embeddings.shape[0], batch_size):
            #batch = train_embeddings[i:i + batch_size]
            #pca.partial_fit(batch)  
        #train_embeddings_reduced = pca.transform(train_embeddings)
        #print("Reduced Training Shape:", train_embeddings_reduced.shape)
        #test_embeddings_reduced = pca.transform(test_embeddings)
        #print("Reduced Test Shape:", test_embeddings_reduced.shape)

        # Train Random Forest model
        #rf_model = RandomForestClassifier(random_state=42, class_weight='balanced', n_jobs=-1)
        #rf_model.fit(train_embeddings, train_labels)
        #rf_probabilities = rf_model.predict_proba(test_embeddings)[:, 1]  # Use probabilities for EER calculation

        
        pipeline = Pipeline([
            #('scaler', StandardScaler()),
            ('classifier', RandomForestClassifier(random_state=42, class_weight='balanced', n_jobs=20))
            #('classifier', SVC(probability=True, random_state=42, class_weight='balanced'))
            #('classifier', KNeighborsClassifier(n_neighbors=20, weights='distance'))
        ])
        #svm_model = SVC(probability=True, random_state=42, class_weight='balanced')
        X, y = shuffle(train_embeddings, train_labels, random_state=42)
        pipeline.fit(X, y)
        probabilities = pipeline.predict_proba(test_embeddings)[:, 1]

        # Calculate EER
        rf_eer = calculate_eer(test_labels, probabilities)

        print(f"Class {cls}: RandomForest EER = {rf_eer:.4f}")

        results[cls] = {
            'RandomForest': {'EER': rf_eer}
        }

    return results

def calculate_mean_std(results):
    """
    Calculate the mean and standard deviation of EER values for each model in the results dictionary.
    
    Args:
        results (dict): A dictionary where keys are classes, and values are dictionaries containing model metrics.
                        Example: {cls: {'RandomForest': {'EER': value}}}
    
    Returns:
        dict: A dictionary containing mean and std for each model across all classes.
    """
    # Extract EER values for each model
    model_eer_values = {}
    for cls, metrics in results.items():
        for model, model_metrics in metrics.items():
            if model not in model_eer_values:
                model_eer_values[model] = []
            model_eer_values[model].append(model_metrics['EER'])
    
    # Calculate mean and std
    model_stats = {}
    for model, eer_values in model_eer_values.items():
        mean = np.mean(eer_values) * 100
        std = np.std(eer_values) * 100
        model_stats[model] = {'mean': mean, 'std': std}
        print(f"Final Average EER {model}: {mean:.4f}")
        print(f"Final EER Standard Deviation {model}: {std:.4f}")
        print(f"${mean:.2f} \\pm {std:.2f}$") 
        
   
    return model_stats

# %%
# Test your pipeline with synthetic data



resutls = classifiers_learn(
    x_test_e, y_test_e, x_test_v, y_test_v, None, x_test_n
)
# Print results
#print("EER:", EERf(resutls))

calculate_mean_std(resutls)
# Out:
# (10000, 465)
# (160051, 465)
# (84408, 465)
# Unique classes:  [ 70  82  85  86  96 103 106 109 111 115 118 119 125 129 130 131 136 145
#  156 159 167 169 173 174 175 176 181 183 184 187 191 192 194 197 199 201
#  203 206 207 214 216 217 219 221 225 230 231 233 236 245 249 250 251 257
#  260 261 262 265 268 270 277 281 282 284 286 291 296 299 301 303 306 310
#  314 322 325 332 336 342 348 354 357 364 365 373 374 384 385 387 402 404
#  407 413 414 415 418 419 422 423 433 436]
# genuine_scores:  1800 0.011366666666666655 impostor_scores 158251 0.00040189319498770183
# Class 70: RandomForest EER = 0.3865
# genuine_scores:  1708 0.0010831381733021083 impostor_scores 158343 0.0001230872220432871
# Class 82: RandomForest EER = 0.4682
# genuine_scores:  1800 0.0003166666666666668 impostor_scores 158251 4.6318822629872187e-05
# Class 85: RandomForest EER = 0.4882
# genuine_scores:  1800 0.04895555555555568 impostor_scores 158251 0.00023001434430114715
# Class 86: RandomForest EER = 0.2468
# genuine_scores:  1700 0.002994117647058807 impostor_scores 158351 8.765337762312738e-05
# Class 96: RandomForest EER = 0.4228
# genuine_scores:  1700 0.0009529411764705888 impostor_scores 158351 0.00010899836439302482
# Class 103: RandomForest EER = 0.4856
# genuine_scores:  4100 0.000253658536585366 impostor_scores 155951 8.188469455149235e-05
# Class 106: RandomForest EER = 0.4921
# genuine_scores:  400 0.0012250000000000006 impostor_scores 159651 9.445603222027885e-05
# Class 109: RandomForest EER = 0.4569
# genuine_scores:  1800 1.1111111111111112e-05 impostor_scores 158251 1.8641272409021013e-05
# Class 111: RandomForest EER = 0.5000
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# genuine_scores:  4100 0.00017073170731707327 impostor_scores 155951 1.231155940006798e-05
# Class 115: RandomForest EER = 0.4944
# genuine_scores:  1800 0.0002222222222222223 impostor_scores 158251 8.973087057901695e-06
# Class 118: RandomForest EER = 0.4935
# genuine_scores:  700 7.142857142857143e-05 impostor_scores 159351 6.884173930505543e-05
# Class 119: RandomForest EER = 0.4984
# genuine_scores:  1800 0.04264999999999999 impostor_scores 158251 0.00016025175196365699
# Class 125: RandomForest EER = 0.3457
# genuine_scores:  400 0.01004999999999999 impostor_scores 159651 0.0004972095383054402
# Class 129: RandomForest EER = 0.3508
# genuine_scores:  1800 0.001522222222222219 impostor_scores 158251 6.887792178248426e-05
# Class 130: RandomForest EER = 0.4688
# genuine_scores:  1800 0.00013888888888888892 impostor_scores 158251 2.925731906907349e-05
# Class 131: RandomForest EER = 0.4953
# genuine_scores:  1800 0.0005500000000000004 impostor_scores 158251 0.00010356964568944122
# Class 136: RandomForest EER = 0.4861
# genuine_scores:  1800 0.0009944444444444451 impostor_scores 158251 2.5213110817624927e-05
# Class 145: RandomForest EER = 0.4809
# genuine_scores:  500 0.0027200000000000006 impostor_scores 159551 4.744564433942685e-05
# Class 156: RandomForest EER = 0.4612
# genuine_scores:  1800 0.0010500000000000008 impostor_scores 158251 1.7946174115803278e-05
# Class 159: RandomForest EER = 0.4684
# genuine_scores:  100 0.0019000000000000002 impostor_scores 159951 0.00029252708642021614
# Class 167: RandomForest EER = 0.4240
# genuine_scores:  500 0.00705999999999998 impostor_scores 159551 0.0005263520755119277
# Class 169: RandomForest EER = 0.3721
# genuine_scores:  500 0.0014600000000000004 impostor_scores 159551 8.799694141684956e-05
# Class 173: RandomForest EER = 0.4589
# genuine_scores:  1800 0.012594444444444457 impostor_scores 158251 0.00018451700147235266
# Class 174: RandomForest EER = 0.3962
# genuine_scores:  500 0.2826600000000001 impostor_scores 159551 8.668074784864982e-05
# Class 175: RandomForest EER = 0.0423
# genuine_scores:  500 0.0005600000000000001 impostor_scores 159551 1.4979536323808647e-05
# Class 176: RandomForest EER = 0.4887
# genuine_scores:  400 2.5e-05 impostor_scores 159651 1.8039348328541573e-05
# Class 181: RandomForest EER = 0.4994
# genuine_scores:  500 0.03029999999999996 impostor_scores 159551 0.00013807497289268196
# Class 183: RandomForest EER = 0.2590
# genuine_scores:  1800 0.0003333333333333335 impostor_scores 158251 2.091613955046084e-05
# Class 184: RandomForest EER = 0.4879
# genuine_scores:  3100 0.0003225806451612905 impostor_scores 156951 9.945779255945999e-05
# Class 187: RandomForest EER = 0.4951
# genuine_scores:  1800 0.00021666666666666674 impostor_scores 158251 9.181616545866855e-05
# Class 191: RandomForest EER = 0.4952
# genuine_scores:  1800 0.0 impostor_scores 158251 8.973087057901695e-06
# Class 192: RandomForest EER = 0.5000
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# genuine_scores:  1800 0.025622222222222248 impostor_scores 158251 9.781928708191287e-05
# Class 194: RandomForest EER = 0.3473
# genuine_scores:  1800 0.04475555555555561 impostor_scores 158251 0.0005199967140808103
# Class 197: RandomForest EER = 0.3072
# genuine_scores:  1800 0.012888888888888906 impostor_scores 158251 0.00016922483902156006
# Class 199: RandomForest EER = 0.3598
# genuine_scores:  1800 0.08846111111111117 impostor_scores 158251 0.0003617670662428626
# Class 201: RandomForest EER = 0.2887
# genuine_scores:  500 0.06990000000000013 impostor_scores 159551 9.721029639425507e-05
# Class 203: RandomForest EER = 0.1803
# genuine_scores:  500 0.14464000000000016 impostor_scores 159551 0.00016226786419389628
# Class 206: RandomForest EER = 0.1380
# genuine_scores:  4000 0.02822750000000002 impostor_scores 156051 0.00019602565827839003
# Class 207: RandomForest EER = 0.3953
# genuine_scores:  1679 0.03631923764145328 impostor_scores 158372 0.000362248377238397
# Class 214: RandomForest EER = 0.2718
# genuine_scores:  500 0.007379999999999988 impostor_scores 159551 0.00011927220763266988
# Class 216: RandomForest EER = 0.3979
# genuine_scores:  500 0.0 impostor_scores 159551 0.00023020852266673585
# Class 217: RandomForest EER = 0.5000
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# genuine_scores:  464 0.01745689655172408 impostor_scores 159587 0.00016649225814132913
# Class 219: RandomForest EER = 0.1960
# genuine_scores:  400 0.0 impostor_scores 159651 3.864679832885449e-05
# Class 221: RandomForest EER = 0.5000
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# genuine_scores:  500 0.00028 impostor_scores 159551 3.892172408822207e-05
# Class 225: RandomForest EER = 0.4888
# genuine_scores:  500 0.03429999999999999 impostor_scores 159551 0.0003583180299716037
# Class 230: RandomForest EER = 0.3217
# genuine_scores:  1800 0.001044444444444445 impostor_scores 158251 8.815110173079328e-05
# Class 231: RandomForest EER = 0.4753
# genuine_scores:  1800 0.0003555555555555558 impostor_scores 158251 0.000143316629910715
# Class 233: RandomForest EER = 0.4905
# genuine_scores:  4100 0.006375609756097573 impostor_scores 155951 0.00021410571269181534
# Class 236: RandomForest EER = 0.4207
# genuine_scores:  500 0.19735999999999998 impostor_scores 159551 0.0007003403300512378
# Class 245: RandomForest EER = 0.0722
# genuine_scores:  4100 0.0008219512195121924 impostor_scores 155951 7.277927041185896e-05
# Class 249: RandomForest EER = 0.4814
# genuine_scores:  4000 0.01652750000000002 impostor_scores 156051 0.00031835746006113265
# Class 250: RandomForest EER = 0.4074
# genuine_scores:  4000 0.002952499999999986 impostor_scores 156051 0.00011694894617785215
# Class 251: RandomForest EER = 0.4574
# genuine_scores:  500 2e-05 impostor_scores 159551 0.0008716335215699095
# Class 257: RandomForest EER = 0.5000
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# genuine_scores:  4800 0.008768750000000028 impostor_scores 155251 0.00014016012779305992
# Class 260: RandomForest EER = 0.3948
# genuine_scores:  900 0.018799999999999966 impostor_scores 159151 0.0005766222015570316
# Class 261: RandomForest EER = 0.4019
# genuine_scores:  500 0.28473999999999966 impostor_scores 159551 0.00038652217786161897
# Class 262: RandomForest EER = 0.0741
# genuine_scores:  3900 0.021735897435897447 impostor_scores 156151 0.0002865175375117675
# Class 265: RandomForest EER = 0.4571
# genuine_scores:  1800 0.040666666666666705 impostor_scores 158251 0.00021573323391321886
# Class 268: RandomForest EER = 0.2918
# genuine_scores:  1800 0.03328333333333333 impostor_scores 158251 0.00028246267006211835
# Class 270: RandomForest EER = 0.4759
# genuine_scores:  1200 0.002566666666666664 impostor_scores 158851 0.00024268024752756065
# Class 277: RandomForest EER = 0.4538
# genuine_scores:  1800 0.0033499999999999845 impostor_scores 158251 0.00013345887229780735
# Class 281: RandomForest EER = 0.4269
# genuine_scores:  400 0.002900000000000001 impostor_scores 159651 5.5182867630017176e-05
# Class 282: RandomForest EER = 0.4450
# genuine_scores:  1800 0.0007833333333333338 impostor_scores 158251 0.00015070994812039527
# Class 284: RandomForest EER = 0.4791
# genuine_scores:  1800 0.002577777777777765 impostor_scores 158251 7.620804923823418e-05
# Class 286: RandomForest EER = 0.4361
# genuine_scores:  1800 0.011161111111111116 impostor_scores 158251 0.00024138868000834397
# Class 291: RandomForest EER = 0.4252
# genuine_scores:  2200 0.0014090909090909026 impostor_scores 157851 7.475404020246863e-05
# Class 296: RandomForest EER = 0.4502
# genuine_scores:  2100 0.017380952380952424 impostor_scores 157951 0.0002706535571158158
# Class 299: RandomForest EER = 0.3219
# genuine_scores:  2200 0.0010181818181818178 impostor_scores 157851 8.336976009021029e-05
# Class 301: RandomForest EER = 0.4783
# genuine_scores:  2000 0.05114500000000025 impostor_scores 158051 0.00018146041467628112
# Class 303: RandomForest EER = 0.1910
# genuine_scores:  2200 0.019395454545454563 impostor_scores 157851 5.5368670455049195e-05
# Class 306: RandomForest EER = 0.4071
# genuine_scores:  2200 5.454545454545454e-05 impostor_scores 157851 3.845398508720209e-05
# Class 310: RandomForest EER = 0.4988
# genuine_scores:  500 0.012599999999999969 impostor_scores 159551 0.00015518548927929399
# Class 314: RandomForest EER = 0.3113
# genuine_scores:  2000 0.06889500000000026 impostor_scores 158051 0.0003629841000689621
# Class 322: RandomForest EER = 0.2450
# genuine_scores:  2100 0.0584619047619049 impostor_scores 157951 0.00018758982216004276
# Class 325: RandomForest EER = 0.1385
# genuine_scores:  300 0.0 impostor_scores 159751 2.3661823713153404e-05
# Class 332: RandomForest EER = 0.5000
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# genuine_scores:  2200 1.3636363636363637e-05 impostor_scores 157851 2.2616264705323174e-05
# Class 336: RandomForest EER = 0.5000
# /home/fallahi/anaconda3/lib/python3.12/site-packages/pyeer/eer_stats.py:220: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# genuine_scores:  2200 0.01835000000000005 impostor_scores 157851 0.00014526357134259687
# Class 342: RandomForest EER = 0.3086
# genuine_scores:  2200 0.002068181818181811 impostor_scores 157851 0.00014070230787261521
# Class 348: RandomForest EER = 0.4580
# genuine_scores:  2200 0.0023409090909090806 impostor_scores 157851 6.670847824847397e-05
# Class 354: RandomForest EER = 0.4498
# genuine_scores:  2100 0.0007380952380952384 impostor_scores 157951 9.332008027805984e-05
# Class 357: RandomForest EER = 0.4849
# genuine_scores:  2100 0.0017904761904761828 impostor_scores 157951 8.762211065456893e-05
# Class 364: RandomForest EER = 0.4517
# genuine_scores:  2900 0.0006724137931034488 impostor_scores 157151 0.00010734898282543444
# Class 365: RandomForest EER = 0.4826
# genuine_scores:  2200 0.0018045454545454478 impostor_scores 157851 9.230223438559044e-05
# Class 373: RandomForest EER = 0.4612
# genuine_scores:  1900 0.04949473684210538 impostor_scores 158151 0.0006765053651257517
# Class 374: RandomForest EER = 0.2122
# genuine_scores:  400 0.001025 impostor_scores 159651 9.802631991030333e-05
# Class 384: RandomForest EER = 0.4740
# genuine_scores:  2100 0.0010809523809523808 impostor_scores 157951 6.767921697235127e-05
# Class 385: RandomForest EER = 0.4670
# genuine_scores:  2200 7.272727272727273e-05 impostor_scores 157851 0.00012429442955698745
# Class 387: RandomForest EER = 0.5000
# genuine_scores:  800 0.003612499999999995 impostor_scores 159251 0.00018894700818205813
# Class 402: RandomForest EER = 0.4297
# genuine_scores:  700 0.0018285714285714296 impostor_scores 159351 5.039190215310789e-05
# Class 404: RandomForest EER = 0.4629
# genuine_scores:  800 0.029387500000000042 impostor_scores 159251 0.00018919818399884861
# Class 407: RandomForest EER = 0.2835
# genuine_scores:  800 0.0014500000000000008 impostor_scores 159251 0.0002732164947158901
# Class 413: RandomForest EER = 0.4537
# genuine_scores:  800 0.023412499999999947 impostor_scores 159251 7.799009111402678e-05
# Class 414: RandomForest EER = 0.3034
# genuine_scores:  800 0.16427500000000006 impostor_scores 159251 0.0003611280305932128
# Class 415: RandomForest EER = 0.0849
# genuine_scores:  800 0.02506250000000001 impostor_scores 159251 0.00015836635248758286
# Class 418: RandomForest EER = 0.4310
# genuine_scores:  800 0.038587500000000066 impostor_scores 159251 0.00037167741489849154
# Class 419: RandomForest EER = 0.3422
# genuine_scores:  700 0.14964285714285722 impostor_scores 159351 0.0003064932130956188
# Class 422: RandomForest EER = 0.1102
# genuine_scores:  800 0.0003500000000000001 impostor_scores 159251 0.00023221204262454073
# Class 423: RandomForest EER = 0.4930
# genuine_scores:  600 0.0012166666666666671 impostor_scores 159451 4.3398912518578936e-05
# Class 433: RandomForest EER = 0.4758
# genuine_scores:  700 0.0412000000000001 impostor_scores 159351 0.0002609334111489746
# Class 436: RandomForest EER = 0.2782
# Final Average EER RandomForest: 39.6092
# Final EER Standard Deviation RandomForest: 11.7555
# $39.61 \pm 11.76$
# {'RandomForest': {'mean': 39.609230596950056, 'std': 11.755465631005755}}
