# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "1"
import numpy as np


from sklearn.metrics.pairwise import euclidean_distances as ed
from sklearn.metrics.pairwise import cosine_distances as cd
from collections import defaultdict
from pyeer.eer_info import get_eer_stats
from sklearn.metrics.pairwise import manhattan_distances as md

from sklearn.metrics.pairwise import cosine_similarity as cs

from pytorch_metric_learning.distances import LpDistance, CosineSimilarity,SNRDistance

def EERf(genuine,impostor):
    genuine = np.array(genuine).ravel()
    impostor = np.array(impostor).ravel()
    #print(genuine.shape, genuine[:5],impostor[:5])
    stats_a = get_eer_stats(genuine, impostor)
    return(stats_a.eer,stats_a.fmr100)


def calculate_and_print_averages(genuine,impostor):
    eer_values = []

    for key in genuine.keys():
        re = EERf(genuine[key],impostor[key])  
        eer_values.append(re[0])  

    average_eer = np.mean(eer_values) * 100
    std_eer = np.std(eer_values) * 100
    return average_eer, std_eer

import torch.nn.functional as F





def calculate_similarity_scores_two(enrollment_embeddings, y_enrollment, verification_embeddings, y_verification,distance):
    similarity_results = []
    similarity_results_by_class = []
    similarity_results_by_class_dict = defaultdict(list)
    unique_classes = np.unique(y_enrollment)
    class_indices = [np.where(y_enrollment == cls)[0] for cls in unique_classes]

    if distance == "cd":
        similarity_matrix = -1 * cd(verification_embeddings, enrollment_embeddings)
    elif distance == "ed":
        similarity_matrix = -1 * ed(verification_embeddings, enrollment_embeddings)

    for i in range(similarity_matrix.shape[0]):
        current_class = y_verification[i]
        predicted_scores = similarity_matrix[i]
        same_class_indices = class_indices[np.where(unique_classes == current_class)[0][0]]

        for cls in unique_classes:
            same_class_indices = class_indices[np.where(unique_classes == cls)[0][0]]
            max_score = sum(sorted(predicted_scores[same_class_indices], reverse=True)[:10]) / 10
            if current_class == cls:
                pass
                #similarity_results_by_class.append([max_score, 1, current_class, cls, i])
                #similarity_results_by_class_dict[cls].append([max_score, 1, current_class, cls, i, cls])
            else:
                similarity_results_by_class.append([max_score, 0, current_class, cls, i])
                similarity_results_by_class_dict[cls].append([max_score])

    return similarity_results_by_class, similarity_results_by_class_dict

def assessment_model_data_two(enrollment_data, ye, verification_data, yv, e_network, distance):
    x_enrollment, y_enrollment = enrollment_data, ye
    x_verification, y_verification = verification_data, yv
    enrollment_embeddings = compute_embedding_batch_two(x_enrollment, e_network)
    verification_embeddings = compute_embedding_batch_two(x_verification, e_network)
    similarity_results_by_class, similarity_results_by_class_dict = calculate_similarity_scores_two(
        enrollment_embeddings, y_enrollment, verification_embeddings, y_verification,distance
    )
    return similarity_results_by_class, similarity_results_by_class_dict




import torch
import numpy as np

def compute_embedding_batch_two(x_test_batch, embedding_network, batch_size=100, device="cuda"):
    #print(x_test_batch.shape)
    return x_test_batch

# %%
# Loading the files with the same names
x_test_e = np.load('x_test_e.npy')
y_test_e = np.load('y_test_e.npy')
s_test_e = np.load('s_test_e.npy')
h_test_e = np.load('h_test_e.npy')

x_test_v = np.load('x_test_v.npy')
y_test_v = np.load('y_test_v.npy')
s_test_v = np.load('s_test_v.npy')
h_test_v = np.load('h_test_v.npy')

# Verify loaded arrays (optional)
print(x_test_e.shape, y_test_e.shape, s_test_e.shape, h_test_e.shape)
print(x_test_v.shape, y_test_v.shape, s_test_v.shape, h_test_v.shape)
results2, impostor = assessment_model_data_two(x_test_e, y_test_e, x_test_v, y_test_v, None, distance='cd')
# Out:
# (10000, 128) (10000,) (10000,) (10000,)
# (160051, 128) (160051,) (160051,) (160051,)

# %%
from collections import defaultdict
import numpy as np
from sklearn.metrics.pairwise import cosine_distances as cd

# Merge the two datasets
x_test = np.concatenate((x_test_e, x_test_v), axis=0)
y_test = np.concatenate((y_test_e, y_test_v), axis=0)
s_test = np.concatenate((s_test_e, s_test_v), axis=0)
h_test = np.concatenate((h_test_e, h_test_v), axis=0)

# Combine into a single data structure
data = {'X': x_test, 'Y': y_test, 'S': s_test, 'H': h_test}

def compute_similarity_per_pair(data):
    similarity_results = defaultdict(lambda: defaultdict(list))  # Pair -> Subject -> Scores

    subjects = np.unique(data['Y'])  # Unique subjects

    for subject in subjects:
        # Filter data for the current subject
        indices = np.where(data['Y'] == subject)[0]
        subject_data = data['X'][indices]
        subject_sessions = data['S'][indices]
        subject_headsets = data['H'][indices]

        # Find the lowest session as enrollment data
        min_session = np.min(subject_sessions)
        enrollment_indices = np.where(subject_sessions == min_session)[0]
        enrollment_data = subject_data[enrollment_indices]
        enrollment_headset = subject_headsets[enrollment_indices[0]]  # Assume same headset for enrollment

        if enrollment_data.ndim == 1:
            enrollment_data = enrollment_data.reshape(1, -1)

        # Iterate through all verification samples (different sessions or headsets)
        verification_indices = np.where(subject_sessions != min_session)[0]
        for i2 in verification_indices:
            verification_sample = subject_data[i2]
            verification_headset = subject_headsets[i2]

            # Ensure verification_sample has the correct shape
            if verification_sample.ndim == 1:
                verification_sample = verification_sample.reshape(1, -1)

 
            distances = -1 * cd(enrollment_data, verification_sample)
            max_score = sum(sorted(distances, reverse=True)[:10]) / 10  # Top-10 average similarity

            # Create a sorted hardware pair key
            pair = tuple(sorted((enrollment_headset, verification_headset)))

            # Store the result: Pair -> Subject -> Scores
            #print(max_score)
            similarity_results[pair][subject].append(max_score)

    return similarity_results

# Example usage
similarity_results = compute_similarity_per_pair(data)

# Print results
for pair, subjects in similarity_results.items():
    print(f"Pair {pair}:")
    for subject, scores in subjects.items():
        avg_score = np.mean(scores)
        print(f"  Subject {subject}: Average Similarity = {avg_score:.4f}, Count = {len(scores)}")
# Out:
# Pair (b'Geodisi', b'HydroCe'):
#   Subject 70: Average Similarity = -0.2521, Count = 1200
#   Subject 85: Average Similarity = -0.3966, Count = 100
#   Subject 86: Average Similarity = -0.2053, Count = 500
#   Subject 96: Average Similarity = -0.3184, Count = 900
#   Subject 103: Average Similarity = -0.2078, Count = 800
#   Subject 106: Average Similarity = -0.3533, Count = 1400
#   Subject 109: Average Similarity = -0.2674, Count = 100
#   Subject 111: Average Similarity = -0.2902, Count = 600
#   Subject 115: Average Similarity = -0.3648, Count = 1500
#   Subject 118: Average Similarity = -0.2801, Count = 800
#   Subject 119: Average Similarity = -0.2946, Count = 400
#   Subject 125: Average Similarity = -0.2214, Count = 1100
#   Subject 129: Average Similarity = -0.2673, Count = 100
#   Subject 130: Average Similarity = -0.1539, Count = 700
#   Subject 131: Average Similarity = -0.3005, Count = 1000
#   Subject 136: Average Similarity = -0.3141, Count = 1300
#   Subject 145: Average Similarity = -0.3384, Count = 900
#   Subject 159: Average Similarity = -0.2168, Count = 1100
#   Subject 174: Average Similarity = -0.3502, Count = 1000
#   Subject 183: Average Similarity = -0.2826, Count = 200
#   Subject 184: Average Similarity = -0.3022, Count = 900
#   Subject 187: Average Similarity = -0.3392, Count = 2900
#   Subject 191: Average Similarity = -0.2947, Count = 900
#   Subject 192: Average Similarity = -0.4808, Count = 1000
#   Subject 194: Average Similarity = -0.2971, Count = 600
#   Subject 197: Average Similarity = -0.3155, Count = 600
#   Subject 199: Average Similarity = -0.3320, Count = 600
#   Subject 201: Average Similarity = -0.2650, Count = 900
#   Subject 207: Average Similarity = -0.2749, Count = 3000
#   Subject 214: Average Similarity = -0.2194, Count = 1079
#   Subject 216: Average Similarity = -0.3674, Count = 200
#   Subject 217: Average Similarity = -0.1938, Count = 500
#   Subject 219: Average Similarity = -0.2513, Count = 100
#   Subject 225: Average Similarity = -0.2969, Count = 300
#   Subject 230: Average Similarity = -0.3610, Count = 200
#   Subject 231: Average Similarity = -0.3320, Count = 800
#   Subject 233: Average Similarity = -0.2637, Count = 1100
#   Subject 236: Average Similarity = -0.4829, Count = 3200
#   Subject 249: Average Similarity = -0.3522, Count = 1800
#   Subject 250: Average Similarity = -0.3992, Count = 2700
#   Subject 251: Average Similarity = -0.2993, Count = 3100
#   Subject 257: Average Similarity = -0.2893, Count = 100
#   Subject 261: Average Similarity = -0.2455, Count = 600
#   Subject 265: Average Similarity = -0.3187, Count = 1500
#   Subject 268: Average Similarity = -0.2587, Count = 600
#   Subject 270: Average Similarity = -0.3372, Count = 600
#   Subject 277: Average Similarity = -0.2273, Count = 800
#   Subject 281: Average Similarity = -0.2576, Count = 900
#   Subject 282: Average Similarity = -0.3017, Count = 200
#   Subject 284: Average Similarity = -0.2573, Count = 700
#   Subject 286: Average Similarity = -0.2713, Count = 400
#   Subject 291: Average Similarity = -0.2585, Count = 1100
# Pair (b'Geodisi', b'Geodisi'):
#   Subject 70: Average Similarity = -0.1896, Count = 600
#   Subject 103: Average Similarity = -0.1699, Count = 900
#   Subject 119: Average Similarity = -0.3770, Count = 300
#   Subject 125: Average Similarity = -0.2196, Count = 700
#   Subject 129: Average Similarity = -0.3162, Count = 300
#   Subject 130: Average Similarity = -0.1585, Count = 1100
#   Subject 131: Average Similarity = -0.3465, Count = 800
#   Subject 136: Average Similarity = -0.2349, Count = 500
#   Subject 167: Average Similarity = -0.2924, Count = 100
#   Subject 174: Average Similarity = -0.3167, Count = 800
#   Subject 184: Average Similarity = -0.2241, Count = 900
#   Subject 187: Average Similarity = -0.2670, Count = 200
#   Subject 191: Average Similarity = -0.2494, Count = 900
#   Subject 201: Average Similarity = -0.2208, Count = 900
#   Subject 207: Average Similarity = -0.2352, Count = 1000
#   Subject 233: Average Similarity = -0.2741, Count = 700
#   Subject 236: Average Similarity = -0.2907, Count = 900
#   Subject 245: Average Similarity = -0.1848, Count = 500
#   Subject 249: Average Similarity = -0.2868, Count = 2300
#   Subject 250: Average Similarity = -0.2035, Count = 1300
#   Subject 251: Average Similarity = -0.1683, Count = 900
#   Subject 268: Average Similarity = -0.2695, Count = 1200
#   Subject 281: Average Similarity = -0.2109, Count = 900
#   Subject 286: Average Similarity = -0.2113, Count = 1400
# Pair (b'HydroCe', b'HydroCe'):
#   Subject 82: Average Similarity = -0.1533, Count = 1708
#   Subject 85: Average Similarity = -0.2222, Count = 1700
#   Subject 86: Average Similarity = -0.1737, Count = 1300
#   Subject 96: Average Similarity = -0.2138, Count = 800
#   Subject 106: Average Similarity = -0.3176, Count = 2700
#   Subject 109: Average Similarity = -0.2084, Count = 300
#   Subject 111: Average Similarity = -0.2549, Count = 1200
#   Subject 115: Average Similarity = -0.3083, Count = 2600
#   Subject 118: Average Similarity = -0.2074, Count = 1000
#   Subject 145: Average Similarity = -0.2252, Count = 900
#   Subject 156: Average Similarity = -0.2037, Count = 500
#   Subject 159: Average Similarity = -0.1740, Count = 700
#   Subject 169: Average Similarity = -0.3003, Count = 500
#   Subject 173: Average Similarity = -0.2449, Count = 500
#   Subject 175: Average Similarity = -0.2424, Count = 500
#   Subject 176: Average Similarity = -0.2631, Count = 500
#   Subject 181: Average Similarity = -0.2983, Count = 400
#   Subject 183: Average Similarity = -0.2612, Count = 300
#   Subject 192: Average Similarity = -0.4650, Count = 800
#   Subject 194: Average Similarity = -0.2709, Count = 1200
#   Subject 197: Average Similarity = -0.2425, Count = 1200
#   Subject 199: Average Similarity = -0.2755, Count = 1200
#   Subject 203: Average Similarity = -0.2080, Count = 500
#   Subject 206: Average Similarity = -0.2358, Count = 500
#   Subject 214: Average Similarity = -0.2148, Count = 600
#   Subject 216: Average Similarity = -0.2205, Count = 300
#   Subject 219: Average Similarity = -0.2535, Count = 364
#   Subject 221: Average Similarity = -0.2535, Count = 400
#   Subject 225: Average Similarity = -0.2013, Count = 200
#   Subject 230: Average Similarity = -0.3306, Count = 300
#   Subject 231: Average Similarity = -0.2636, Count = 1000
#   Subject 257: Average Similarity = -0.2872, Count = 400
#   Subject 260: Average Similarity = -0.2993, Count = 4000
#   Subject 261: Average Similarity = -0.2659, Count = 300
#   Subject 262: Average Similarity = -0.1623, Count = 500
#   Subject 265: Average Similarity = -0.2614, Count = 2400
#   Subject 270: Average Similarity = -0.4134, Count = 1200
#   Subject 277: Average Similarity = -0.1950, Count = 400
#   Subject 282: Average Similarity = -0.1864, Count = 200
#   Subject 284: Average Similarity = -0.2245, Count = 1100
#   Subject 291: Average Similarity = -0.2178, Count = 700
#   Subject 296: Average Similarity = -0.3869, Count = 2200
#   Subject 299: Average Similarity = -0.2260, Count = 2100
#   Subject 301: Average Similarity = -0.2106, Count = 2200
#   Subject 303: Average Similarity = -0.2046, Count = 2000
#   Subject 306: Average Similarity = -0.3077, Count = 2200
#   Subject 310: Average Similarity = -0.2115, Count = 2200
#   Subject 314: Average Similarity = -0.1768, Count = 500
#   Subject 322: Average Similarity = -0.2267, Count = 2000
#   Subject 325: Average Similarity = -0.2126, Count = 2100
# Pair (b'BioSemi', b'HydroCe'):
#   Subject 260: Average Similarity = -0.7151, Count = 800
#   Subject 332: Average Similarity = -0.4873, Count = 100
# Pair (b'BioSemi', b'BioSemi'):
#   Subject 332: Average Similarity = -0.2211, Count = 200
#   Subject 336: Average Similarity = -0.3737, Count = 2200
#   Subject 342: Average Similarity = -0.2350, Count = 2200
#   Subject 348: Average Similarity = -0.3137, Count = 2200
#   Subject 354: Average Similarity = -0.2231, Count = 2200
#   Subject 357: Average Similarity = -0.2835, Count = 2100
#   Subject 364: Average Similarity = -0.2196, Count = 2100
#   Subject 365: Average Similarity = -0.2566, Count = 2900
#   Subject 373: Average Similarity = -0.2125, Count = 2200
#   Subject 374: Average Similarity = -0.1993, Count = 1900
#   Subject 384: Average Similarity = -0.2503, Count = 400
#   Subject 385: Average Similarity = -0.1950, Count = 2100
#   Subject 387: Average Similarity = -0.2295, Count = 2200
#   Subject 402: Average Similarity = -0.2233, Count = 800
#   Subject 404: Average Similarity = -0.2014, Count = 700
#   Subject 407: Average Similarity = -0.2583, Count = 800
#   Subject 413: Average Similarity = -0.2561, Count = 800
#   Subject 414: Average Similarity = -0.2315, Count = 800
#   Subject 415: Average Similarity = -0.1935, Count = 800
#   Subject 418: Average Similarity = -0.2707, Count = 800
#   Subject 419: Average Similarity = -0.2412, Count = 800
#   Subject 422: Average Similarity = -0.2426, Count = 700
#   Subject 423: Average Similarity = -0.2022, Count = 800
#   Subject 433: Average Similarity = -0.2150, Count = 600
#   Subject 436: Average Similarity = -0.2467, Count = 700

# %%
from sklearn.metrics.pairwise import cosine_distances as cd
from collections import defaultdict
import numpy as np

def compute_similarity_per_pair(data):
    similarity_results = defaultdict(lambda: defaultdict(list))  # Pair -> Subject -> Scores

    subjects = np.unique(data['Y'])  # Unique subjects

    for subject in subjects:
        # Filter data for the current subject
        indices = np.where(data['Y'] == subject)[0]
        subject_data = data['X'][indices]
        subject_sessions = data['S'][indices]
        subject_headsets = data['H'][indices]

        # Combine session and hardware into unique pairs
        session_hardware_pairs = list(set(zip(subject_sessions, subject_headsets)))
        session_hardware_pairs.sort()  # Ensure consistent ordering by session number

        # Loop through all pairs of (session, hardware)
        for (sess1, hw1) in session_hardware_pairs:
            for (sess2, hw2) in session_hardware_pairs:
                if sess1 < sess2:  # Enforce lower session as enrollment
                    # Find enrollment data
                    enrollment_indices = np.where((subject_sessions == sess1) & (subject_headsets == hw1))[0]
                    enrollment_data = subject_data[enrollment_indices]
                    if enrollment_data.ndim == 1:
                        enrollment_data = enrollment_data.reshape(1, -1)
                    enrollment_hw = hw1

                    # Find verification data
                    verification_indices = np.where((subject_sessions == sess2) & (subject_headsets == hw2))[0]
                    for i2 in verification_indices:
                        verification_sample = subject_data[i2]
                        verification_hw = hw2

                        # Ensure verification_sample has the correct shape
                        if verification_sample.ndim == 1:
                            verification_sample = verification_sample.reshape(1, -1)

                        # Compute cosine similarity
                        distances = -1 * cd(enrollment_data, verification_sample)
                        max_score = sum(sorted(distances, reverse=True)[:10]) / 10

                        # Create a sorted hardware pair key
                        pair = tuple(sorted((enrollment_hw, verification_hw)))

                        # Append similarity score
                        similarity_results[pair][subject].append(float(max_score.item()))

    return similarity_results

# Example usage
similarity_results = compute_similarity_per_pair(data)

# Print results
for pair, subjects in similarity_results.items():
    print(f"Pair {pair}:")
    for subject, scores in subjects.items():
        avg_score = np.mean(scores)
        print(f"  Subject {subject}: Average Similarity = {avg_score:.4f}, Count = {len(scores)}")
# Out:
# Pair (b'Geodisi', b'HydroCe'):
#   Subject 70: Average Similarity = -0.2451, Count = 8400
#   Subject 85: Average Similarity = -0.3566, Count = 1800
#   Subject 86: Average Similarity = -0.1960, Count = 7000
#   Subject 96: Average Similarity = -0.2903, Count = 8100
#   Subject 103: Average Similarity = -0.2103, Count = 8000
#   Subject 106: Average Similarity = -0.3181, Count = 36700
#   Subject 109: Average Similarity = -0.2614, Count = 400
#   Subject 111: Average Similarity = -0.2636, Count = 7800
#   Subject 115: Average Similarity = -0.3721, Count = 40300
#   Subject 118: Average Similarity = -0.2940, Count = 8800
#   Subject 119: Average Similarity = -0.2968, Count = 1600
#   Subject 125: Average Similarity = -0.2303, Count = 8800
#   Subject 129: Average Similarity = -0.3274, Count = 400
#   Subject 130: Average Similarity = -0.1812, Count = 8400
#   Subject 131: Average Similarity = -0.3695, Count = 9000
#   Subject 136: Average Similarity = -0.2934, Count = 7800
#   Subject 145: Average Similarity = -0.2796, Count = 9000
#   Subject 159: Average Similarity = -0.2292, Count = 8800
#   Subject 174: Average Similarity = -0.3669, Count = 9000
#   Subject 183: Average Similarity = -0.3064, Count = 800
#   Subject 184: Average Similarity = -0.2452, Count = 9000
#   Subject 187: Average Similarity = -0.3373, Count = 8700
#   Subject 191: Average Similarity = -0.3030, Count = 9000
#   Subject 192: Average Similarity = -0.3658, Count = 9000
#   Subject 194: Average Similarity = -0.2710, Count = 7800
#   Subject 197: Average Similarity = -0.3112, Count = 7800
#   Subject 199: Average Similarity = -0.3191, Count = 7800
#   Subject 201: Average Similarity = -0.2831, Count = 9000
#   Subject 207: Average Similarity = -0.3151, Count = 33000
#   Subject 214: Average Similarity = -0.2404, Count = 7574
#   Subject 216: Average Similarity = -0.3310, Count = 800
#   Subject 217: Average Similarity = -0.1938, Count = 500
#   Subject 219: Average Similarity = -0.2646, Count = 464
#   Subject 225: Average Similarity = -0.2588, Count = 900
#   Subject 230: Average Similarity = -0.3163, Count = 800
#   Subject 231: Average Similarity = -0.2859, Count = 8800
#   Subject 233: Average Similarity = -0.2807, Count = 8800
#   Subject 236: Average Similarity = -0.4222, Count = 32000
#   Subject 249: Average Similarity = -0.2922, Count = 43200
#   Subject 250: Average Similarity = -0.3772, Count = 37800
#   Subject 251: Average Similarity = -0.3019, Count = 31000
#   Subject 257: Average Similarity = -0.2186, Count = 500
#   Subject 261: Average Similarity = -0.2874, Count = 2400
#   Subject 265: Average Similarity = -0.2785, Count = 37500
#   Subject 268: Average Similarity = -0.2481, Count = 7800
#   Subject 270: Average Similarity = -0.2099, Count = 7800
#   Subject 277: Average Similarity = -0.2332, Count = 4000
#   Subject 281: Average Similarity = -0.2278, Count = 9000
#   Subject 282: Average Similarity = -0.2892, Count = 600
#   Subject 284: Average Similarity = -0.2412, Count = 8400
#   Subject 286: Average Similarity = -0.2640, Count = 6000
#   Subject 291: Average Similarity = -0.2335, Count = 8800
# Pair (b'Geodisi', b'Geodisi'):
#   Subject 70: Average Similarity = -0.1946, Count = 2100
#   Subject 86: Average Similarity = -0.1441, Count = 1000
#   Subject 96: Average Similarity = -0.2430, Count = 3600
#   Subject 103: Average Similarity = -0.1512, Count = 4500
#   Subject 106: Average Similarity = -0.2743, Count = 8100
#   Subject 111: Average Similarity = -0.2732, Count = 1500
#   Subject 115: Average Similarity = -0.3270, Count = 10500
#   Subject 118: Average Similarity = -0.2602, Count = 2800
#   Subject 119: Average Similarity = -0.3326, Count = 600
#   Subject 125: Average Similarity = -0.2177, Count = 2800
#   Subject 129: Average Similarity = -0.2923, Count = 600
#   Subject 130: Average Similarity = -0.1728, Count = 6600
#   Subject 131: Average Similarity = -0.3656, Count = 3600
#   Subject 136: Average Similarity = -0.2430, Count = 1500
#   Subject 145: Average Similarity = -0.2638, Count = 3600
#   Subject 159: Average Similarity = -0.2093, Count = 5500
#   Subject 167: Average Similarity = -0.2924, Count = 100
#   Subject 174: Average Similarity = -0.3453, Count = 3600
#   Subject 183: Average Similarity = -0.1876, Count = 100
#   Subject 184: Average Similarity = -0.2015, Count = 4500
#   Subject 187: Average Similarity = -0.2592, Count = 300
#   Subject 191: Average Similarity = -0.2762, Count = 4500
#   Subject 192: Average Similarity = -0.3226, Count = 4500
#   Subject 194: Average Similarity = -0.2570, Count = 1500
#   Subject 197: Average Similarity = -0.2914, Count = 1500
#   Subject 199: Average Similarity = -0.2909, Count = 1500
#   Subject 201: Average Similarity = -0.2373, Count = 4500
#   Subject 207: Average Similarity = -0.2595, Count = 5500
#   Subject 214: Average Similarity = -0.2031, Count = 5353
#   Subject 216: Average Similarity = -0.2146, Count = 100
#   Subject 225: Average Similarity = -0.1816, Count = 300
#   Subject 230: Average Similarity = -0.2693, Count = 100
#   Subject 231: Average Similarity = -0.2514, Count = 2800
#   Subject 233: Average Similarity = -0.2684, Count = 2800
#   Subject 236: Average Similarity = -0.2476, Count = 4500
#   Subject 245: Average Similarity = -0.1843, Count = 1500
#   Subject 249: Average Similarity = -0.2299, Count = 27600
#   Subject 250: Average Similarity = -0.2191, Count = 9100
#   Subject 251: Average Similarity = -0.1693, Count = 4500
#   Subject 261: Average Similarity = -0.2246, Count = 1500
#   Subject 265: Average Similarity = -0.2129, Count = 10500
#   Subject 268: Average Similarity = -0.2493, Count = 7800
#   Subject 270: Average Similarity = -0.1806, Count = 1500
#   Subject 277: Average Similarity = -0.2318, Count = 2800
#   Subject 281: Average Similarity = -0.2048, Count = 4500
#   Subject 282: Average Similarity = -0.2442, Count = 100
#   Subject 284: Average Similarity = -0.2119, Count = 2100
#   Subject 286: Average Similarity = -0.2171, Count = 10500
#   Subject 291: Average Similarity = -0.2087, Count = 5500
# Pair (b'HydroCe', b'HydroCe'):
#   Subject 70: Average Similarity = -0.2352, Count = 6600
#   Subject 82: Average Similarity = -0.1679, Count = 16088
#   Subject 85: Average Similarity = -0.2475, Count = 15300
#   Subject 86: Average Similarity = -0.1617, Count = 9100
#   Subject 96: Average Similarity = -0.2038, Count = 3600
#   Subject 103: Average Similarity = -0.1759, Count = 2800
#   Subject 106: Average Similarity = -0.3249, Count = 37800
#   Subject 109: Average Similarity = -0.2098, Count = 600
#   Subject 111: Average Similarity = -0.2376, Count = 7800
#   Subject 115: Average Similarity = -0.3303, Count = 34800
#   Subject 118: Average Similarity = -0.2261, Count = 5500
#   Subject 119: Average Similarity = -0.2552, Count = 600
#   Subject 125: Average Similarity = -0.2007, Count = 5500
#   Subject 130: Average Similarity = -0.1336, Count = 2100
#   Subject 131: Average Similarity = -0.2740, Count = 4500
#   Subject 136: Average Similarity = -0.2286, Count = 7800
#   Subject 145: Average Similarity = -0.2172, Count = 4500
#   Subject 156: Average Similarity = -0.1840, Count = 1500
#   Subject 159: Average Similarity = -0.1904, Count = 2800
#   Subject 169: Average Similarity = -0.2961, Count = 1500
#   Subject 173: Average Similarity = -0.2607, Count = 1500
#   Subject 174: Average Similarity = -0.3849, Count = 4500
#   Subject 175: Average Similarity = -0.2463, Count = 1500
#   Subject 176: Average Similarity = -0.3218, Count = 1500
#   Subject 181: Average Similarity = -0.2417, Count = 1000
#   Subject 183: Average Similarity = -0.2348, Count = 600
#   Subject 184: Average Similarity = -0.1985, Count = 3600
#   Subject 187: Average Similarity = -0.3685, Count = 40600
#   Subject 191: Average Similarity = -0.2298, Count = 3600
#   Subject 192: Average Similarity = -0.3504, Count = 3600
#   Subject 194: Average Similarity = -0.2548, Count = 7800
#   Subject 197: Average Similarity = -0.2399, Count = 7800
#   Subject 199: Average Similarity = -0.2643, Count = 7800
#   Subject 201: Average Similarity = -0.2690, Count = 3600
#   Subject 203: Average Similarity = -0.2117, Count = 1500
#   Subject 206: Average Similarity = -0.2143, Count = 1500
#   Subject 207: Average Similarity = -0.2898, Count = 43500
#   Subject 214: Average Similarity = -0.2001, Count = 2100
#   Subject 216: Average Similarity = -0.2212, Count = 600
#   Subject 217: Average Similarity = -0.0977, Count = 1000
#   Subject 219: Average Similarity = -0.2490, Count = 792
#   Subject 221: Average Similarity = -0.2332, Count = 1000
#   Subject 225: Average Similarity = -0.1877, Count = 300
#   Subject 230: Average Similarity = -0.2952, Count = 600
#   Subject 231: Average Similarity = -0.2438, Count = 5500
#   Subject 233: Average Similarity = -0.2308, Count = 5500
#   Subject 236: Average Similarity = -0.3082, Count = 49600
#   Subject 249: Average Similarity = -0.3221, Count = 15300
#   Subject 250: Average Similarity = -0.2712, Count = 35100
#   Subject 251: Average Similarity = -0.3004, Count = 46500
#   Subject 257: Average Similarity = -0.2090, Count = 1000
#   Subject 260: Average Similarity = -0.2588, Count = 82000
#   Subject 261: Average Similarity = -0.3098, Count = 600
#   Subject 262: Average Similarity = -0.1585, Count = 1500
#   Subject 265: Average Similarity = -0.2610, Count = 30000
#   Subject 268: Average Similarity = -0.2189, Count = 1500
#   Subject 270: Average Similarity = -0.2264, Count = 7800
#   Subject 277: Average Similarity = -0.1906, Count = 1000
#   Subject 281: Average Similarity = -0.2138, Count = 3600
#   Subject 282: Average Similarity = -0.1806, Count = 300
#   Subject 284: Average Similarity = -0.2385, Count = 6600
#   Subject 286: Average Similarity = -0.2203, Count = 600
#   Subject 291: Average Similarity = -0.2196, Count = 2800
#   Subject 296: Average Similarity = -0.2585, Count = 25300
#   Subject 299: Average Similarity = -0.2277, Count = 23100
#   Subject 301: Average Similarity = -0.1909, Count = 25300
#   Subject 303: Average Similarity = -0.2076, Count = 21000
#   Subject 306: Average Similarity = -0.2147, Count = 25300
#   Subject 310: Average Similarity = -0.2037, Count = 25300
#   Subject 314: Average Similarity = -0.2020, Count = 1500
#   Subject 322: Average Similarity = -0.2235, Count = 21000
#   Subject 325: Average Similarity = -0.2295, Count = 23100
# Pair (b'BioSemi', b'HydroCe'):
#   Subject 260: Average Similarity = -0.7952, Count = 32800
#   Subject 332: Average Similarity = -0.4329, Count = 300
# Pair (b'BioSemi', b'BioSemi'):
#   Subject 260: Average Similarity = -0.2305, Count = 2800
#   Subject 332: Average Similarity = -0.2315, Count = 300
#   Subject 336: Average Similarity = -0.2704, Count = 25300
#   Subject 342: Average Similarity = -0.2413, Count = 25300
#   Subject 348: Average Similarity = -0.2706, Count = 25300
#   Subject 354: Average Similarity = -0.2121, Count = 25300
#   Subject 357: Average Similarity = -0.2719, Count = 23100
#   Subject 364: Average Similarity = -0.2108, Count = 23100
#   Subject 365: Average Similarity = -0.2489, Count = 43500
#   Subject 373: Average Similarity = -0.2314, Count = 25300
#   Subject 374: Average Similarity = -0.2152, Count = 19000
#   Subject 384: Average Similarity = -0.2519, Count = 1000
#   Subject 385: Average Similarity = -0.2122, Count = 23100
#   Subject 387: Average Similarity = -0.2162, Count = 25300
#   Subject 402: Average Similarity = -0.2216, Count = 3600
#   Subject 404: Average Similarity = -0.1923, Count = 2800
#   Subject 407: Average Similarity = -0.2686, Count = 3600
#   Subject 413: Average Similarity = -0.2588, Count = 3600
#   Subject 414: Average Similarity = -0.2354, Count = 3600
#   Subject 415: Average Similarity = -0.2061, Count = 3600
#   Subject 418: Average Similarity = -0.2719, Count = 3600
#   Subject 419: Average Similarity = -0.2467, Count = 3600
#   Subject 422: Average Similarity = -0.2456, Count = 2800
#   Subject 423: Average Similarity = -0.2045, Count = 3600
#   Subject 433: Average Similarity = -0.2564, Count = 2100
#   Subject 436: Average Similarity = -0.2510, Count = 2800

# %%
calculate_and_print_averages(similarity_results[(b'Geodisi', b'HydroCe')],impostor)
# Out:
# (13.25206861038949, 6.383754496119846)

# %%
calculate_and_print_averages(similarity_results[(b'BioSemi', b'HydroCe')],impostor)
# Out:
# /home/fallahi/anaconda3/envs/oml/lib/python3.9/site-packages/pyeer/eer_stats.py:219: UserWarning: It is possible that you had set the wrong score type. Please consider reviewing if you are using dissimilarity or similarity scores
#   warn("It is possible that you had set the wrong score"
# (48.20999544620841, 28.876722623711732)

# %%
# Function to calculate all possible hardware pairs from unique triplets and count unique subjects per pair
def calculate_hardware_pairs_with_subjects(unique_triplets):
    all_pairs = {}
    subject_counts = {}
    subjects = np.unique(unique_triplets['label'])

    for subject in subjects:
        subject_triplets = unique_triplets[unique_triplets['label'] == subject]
        hardware_combinations = subject_triplets['hardware']

        # Generate all pairs for this subject including pairs from the same hardware in different sessions
        for i in range(len(hardware_combinations)):
            for j in range(i + 1, len(hardware_combinations)):
                pair = tuple(sorted((hardware_combinations[i], hardware_combinations[j])))
                
                # Count total occurrences of the pair
                all_pairs[pair] = all_pairs.get(pair, 0) + 1

                # Add subject to the pair-specific set
                if pair not in subject_counts:
                    subject_counts[pair] = set()
                subject_counts[pair].add(subject)

    # Convert subject sets to unique counts
    unique_subject_counts = {pair: len(subjects) for pair, subjects in subject_counts.items()}
    
    return all_pairs, unique_subject_counts

# Run the updated function
hardware_pairs, subject_counts = calculate_hardware_pairs_with_subjects(unique_triplets)

# Print results
print("All possible hardware pairs used by subjects (including same hardware in different sessions):")
for pair, count in hardware_pairs.items():
    print(f"Pair {pair}: {count} times, Unique Subjects: {subject_counts[pair]}")
# Out:
# All possible hardware pairs used by subjects (including same hardware in different sessions):
# Pair (b'Geodisi', b'HydroCe'): 5559 times, Unique Subjects: 52
# Pair (b'Geodisi', b'Geodisi'): 1963 times, Unique Subjects: 49
# Pair (b'HydroCe', b'HydroCe'): 7989 times, Unique Subjects: 72
# Pair (b'BioSemi', b'HydroCe'): 331 times, Unique Subjects: 2
# Pair (b'BioSemi', b'BioSemi'): 3270 times, Unique Subjects: 26
