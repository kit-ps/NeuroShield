# %%
import os
import numpy as np
from torchsummary import summary
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
feature= "raw"
sample_len = 500
num_epochs=99
batch_s= 128

from torch.optim import Adam, AdamW, SGD, RMSprop
from torch.optim.lr_scheduler import MultiStepLR
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from pytorch_metric_learning import distances, losses, miners, reducers, testers
from pytorch_metric_learning.utils.accuracy_calculator import AccuracyCalculator
from pytorch_metric_learning import losses, miners, samplers, testers, trainers
import torch.nn as nn
import torch.nn.functional as F
from pytorch_metric_learning import losses, regularizers
from sklearn.metrics.pairwise import euclidean_distances as ed
from sklearn.metrics.pairwise import cosine_distances as cd
from collections import defaultdict
from pyeer.eer_info import get_eer_stats
from sklearn.metrics.pairwise import manhattan_distances as md

from sklearn.metrics.pairwise import cosine_similarity as cs

from pytorch_metric_learning.distances import LpDistance, CosineSimilarity,SNRDistance


import h5py
import torch
import numpy as np
from torch.utils.data import Dataset, DataLoader, Subset
class EEGDataset(Dataset):
    def __init__(self, h5_file_path):
        # Open the HDF5 file
        self.h5_file = h5py.File(h5_file_path, 'r')

        # Access the data and labels from the HDF5 file
        self.x_data = self.h5_file['data']  # EEG data (use memory-mapped access)
        self.y_data = self.h5_file['labels'][:]  # Labels (load fully into memory)
        self.s_data = self.h5_file['sessions'][:]  # Sessions (load fully into memory)

        # Create a mapping from original subject labels to new integer labels (starting from 1)
        unique_subjects = np.unique(self.y_data)  # Get unique subject labels
        self.subject_map = {subject: idx for idx, subject in enumerate(unique_subjects)}  # Map to range [1, len(unique_subjects)]

        #print(self.subject_map)

        # Map the y_data labels using the subject_map
        self.y_data_mapped = np.array([self.subject_map[subject] for subject in self.y_data])

        # Convert labels to torch tensors
        self.targets = torch.tensor(self.y_data_mapped, dtype=torch.long)

        # Print the number of unique subjects (labels)
        print(f'Number of unique subjects: {len(unique_subjects)}')

    def __len__(self):
        return len(self.x_data)

    def __getitem__(self, idx):
        x_tensor = torch.tensor(self.x_data[idx], dtype=torch.float32)  # Convert to torch tensor
        y_tensor = self.targets[idx]  # Fetch the preloaded label tensor
        session = self.s_data[idx]  # Session info

        return x_tensor, y_tensor, session

    def close(self):
        self.h5_file.close()


class EEGDataset(Dataset):
    def __init__(self, h5_file_path):
        # Open the HDF5 file
        with h5py.File(h5_file_path, 'r') as h5_file:
            # Load the data, labels, and sessions fully into memory
            self.x_data = np.array(h5_file['data'])  # Load EEG data into memory
            self.y_data = np.array(h5_file['labels'])  # Load labels into memory
            self.s_data = np.array(h5_file['sessions'])  # Load sessions into memory

        # Create a mapping from original subject labels to new integer labels (starting from 1)
        unique_subjects = np.unique(self.y_data)  # Get unique subject labels
        self.subject_map = {subject: idx for idx, subject in enumerate(unique_subjects)}  # Map to range [1, len(unique_subjects)]

        # Map the y_data labels using the subject_map
        self.y_data_mapped = np.array([self.subject_map[subject] for subject in self.y_data])

        # Convert labels to torch tensors
        self.targets = torch.tensor(self.y_data_mapped, dtype=torch.long)

        # Print the number of unique subjects (labels)
        print(f'Number of unique subjects: {len(unique_subjects)}')

    def __len__(self):
        return len(self.x_data)

    def __getitem__(self, idx):
        # Convert data and labels into torch tensors
        x_tensor = torch.tensor(self.x_data[idx], dtype=torch.float32)  # Fetch EEG data
        y_tensor = self.targets[idx]  # Fetch the preloaded label tensor
        session = self.s_data[idx]  # Fetch the session info

        return x_tensor, y_tensor, session

# Usage example
h5_file_path_t = f'../Data/train_{feature}.h5'
h5_file_path_v = f'../Data/valid_{feature}.h5'
train_dataset = EEGDataset(h5_file_path_t)
valid_dataset = EEGDataset(h5_file_path_v)
#valid_loader = DataLoader(valid_dataset, batch_size=128, shuffle=True)


import torch
import numpy as np

# Example data
subject_ids = train_dataset.targets  # Replace with train_dataset.targets
session_ids = train_dataset.s_data          # Replace with train_dataset.s_data

# Combine subject and session IDs into unique pairs
pairs = list(zip(subject_ids.tolist(), session_ids.tolist()))

# Create a mapping from pairs to unique IDs
unique_pairs = list(set(pairs))  # Get unique pairs
pair_to_id = {pair: idx for idx, pair in enumerate(unique_pairs)}

# Map each pair to its unique ID
unique_ids = torch.tensor([pair_to_id[pair] for pair in pairs])

import torch
import torch.nn as nn

def validate(model, loader, loss_func, mining_func, device):
    model.eval()
    total_loss = 0.0
    total_batches = 0

    with torch.no_grad():
        # Iterate over the validation loader (using the provided loader, not train_loader)
        for batch_idx, (data, labels, sessions) in enumerate(loader):
            # Move data and labels to the specified device
            inputs = data.to(device)
            targets = labels.to(device)

            # Compute embeddings using the model
            embeddings = model(inputs)
            
            # Get mining output for the embeddings
            mined_indices = mining_func(embeddings, targets)
            
            # Calculate loss
            loss = loss_func(embeddings, targets, mined_indices)

            total_loss += loss.item()
            total_batches += 1

    # Compute the average validation loss
    average_loss = total_loss / total_batches if total_batches > 0 else 0
    return average_loss


import torch.nn as nn

class EEGNet7(nn.Module):
    def __init__(self):
        super(EEGNet7, self).__init__()
        # InstanceNorm1d normalizes each channel across its 500 values for each sample
        self.norm = nn.InstanceNorm1d(93, affine=False)  # Normalizes across the 500 values in each of the 93 channels
        self.act = nn.ReLU()  # or nn.SELU() , ReLU
        self.act2 = nn.Tanh()
        self.conv1 = nn.Conv2d(1, 256, (1, 4), padding='same')
        self.pool1 = nn.MaxPool2d((1, 2))
        self.conv2 = nn.Conv2d(256, 192, (4, 1), padding='same')
        self.pool2 = nn.MaxPool2d((2, 1))
        self.conv3 = nn.Conv2d(192, 128, (1, 4), padding='same')
        self.pool3 = nn.MaxPool2d((1, 2))
        self.conv4 = nn.Conv2d(128, 96, (4, 1), padding='same')
        self.pool4 = nn.MaxPool2d((2, 1))
        self.conv5 = nn.Conv2d(96, 64, (1, 4), padding='same')
        self.pool5 = nn.MaxPool2d((1, 2))
        self.conv6 = nn.Conv2d(64, 32, (4, 1), padding='same')
        self.pool6 = nn.MaxPool2d((2, 1))
        self.conv7 = nn.Conv2d(32, 16, (1, 2), padding='same')
        self.conv8 = nn.Conv2d(16, 2, (2, 1), padding='same')
        self.flatten = nn.Flatten()
        self.embedding = nn.Linear(1364, 128)  # Embedding layer

    def forward(self, x):
        #if x.dim() == 3:
            #x = x.unsqueeze(1)  # Adding a channel dimension if input is 3D
        x = self.norm(x)  # Apply InstanceNorm along the channel dimension (squeeze to 1D first)
        x = x.unsqueeze(1)  # Reshape to 4D again for Conv2d
        x = self.act(self.conv1(x))
        x = self.pool1(x)
        x = self.act(self.conv2(x))
        x = self.pool2(x)
        x = self.act(self.conv3(x))
        x = self.pool3(x)
        x = self.act(self.conv4(x))
        x = self.pool4(x)
        x = self.act(self.conv5(x))
        x = self.pool5(x)
        x = self.act(self.conv6(x))
        x = self.pool6(x)
        x = self.act(self.conv7(x))
        x = self.act(self.conv8(x))
        x = self.flatten(x)
        x = self.embedding(x)
        return x




from torch.cuda.amp import autocast, GradScaler

scaler = GradScaler()

def train(model, loss_func, mining_func, device, train_loader, optimizer, epoch, test_loader):
    model.train()
    total_batches = len(train_loader)
    print(f"Total number of batches in train_loader: {total_batches}")

    for batch_idx, (data, labels, sessions) in enumerate(train_loader):
        data, labels = data.to(device), labels.to(device)
        optimizer.zero_grad()

        # Use mixed precision training
        with autocast():
            embeddings = model(data)
            indices_tuple = mining_func(embeddings, labels)
            loss = loss_func(embeddings, labels, indices_tuple)

        # Scales the loss, and backward pass
        scaler.scale(loss).backward()

        # Unscales gradients and optimizer step
        scaler.step(optimizer)
        scaler.update()

        if batch_idx % 100 == 0:
            print(
                "Epoch {} Iteration {}: Loss = {}, Number of mined triplets = {} ".format(
                    epoch, batch_idx, loss.item(), mining_func.num_triplets
                )
            )
    val_loss = validate(model, test_loader, loss_func, mining_func, device)
    print("Validation loss: ", val_loss)








device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
trunk = EEGNet7().to(device)
summary(trunk, (93, sample_len)) 

#loss_func = losses.SupConLoss(temperature=0.1).to(device)
#loss_func = losses.SoftTripleLoss(230, 128).to(device)
loss_func = losses.TripletMarginLoss(margin=0.5).to(device)
mining_func = miners.TripletMarginMiner(margin=0.5)

#sampler = samplers.MPerClassSampler(unique_ids, m=1, batch_size=batch_s)
sampler = samplers.MPerClassSampler(train_dataset.targets, m=4, batch_size=batch_s)


train_loader = DataLoader(train_dataset, batch_size=batch_s, sampler=sampler)
trunk_optimizer = torch.optim.Adam(trunk.parameters(), lr=0.0001)
#mining_func = miners.PairMarginMiner(pos_margin=0.20, neg_margin=0.8)


sampler2 = samplers.MPerClassSampler(valid_dataset.targets, m=4, batch_size=32)
valid_loader = DataLoader(valid_dataset, batch_size=batch_s, sampler=sampler2)

for epoch in range(1, num_epochs + 1):
    train(trunk, loss_func, mining_func, device, train_loader, trunk_optimizer, epoch,valid_loader)
    #test(trunk, loss_func, mining_func, device, test_loader)





torch.save(trunk.state_dict(), './model/TripletMarginMiner128_m4_e99.pth')
# Out:
# Number of unique subjects: 230
# Number of unique subjects: 15
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#     InstanceNorm1d-1              [-1, 93, 500]               0
#             Conv2d-2         [-1, 256, 93, 500]           1,280
#               ReLU-3         [-1, 256, 93, 500]               0
#          MaxPool2d-4         [-1, 256, 93, 250]               0
#             Conv2d-5         [-1, 192, 93, 250]         196,800
#               ReLU-6         [-1, 192, 93, 250]               0
#          MaxPool2d-7         [-1, 192, 46, 250]               0
#             Conv2d-8         [-1, 128, 46, 250]          98,432
#               ReLU-9         [-1, 128, 46, 250]               0
#         MaxPool2d-10         [-1, 128, 46, 125]               0
#            Conv2d-11          [-1, 96, 46, 125]          49,248
#              ReLU-12          [-1, 96, 46, 125]               0
#         MaxPool2d-13          [-1, 96, 23, 125]               0
#            Conv2d-14          [-1, 64, 23, 125]          24,640
#              ReLU-15          [-1, 64, 23, 125]               0
#         MaxPool2d-16           [-1, 64, 23, 62]               0
#            Conv2d-17           [-1, 32, 23, 62]           8,224
#              ReLU-18           [-1, 32, 23, 62]               0
#         MaxPool2d-19           [-1, 32, 11, 62]               0
#            Conv2d-20           [-1, 16, 11, 62]           1,040
#              ReLU-21           [-1, 16, 11, 62]               0
#            Conv2d-22            [-1, 2, 11, 62]              66
#              ReLU-23            [-1, 2, 11, 62]               0
#           Flatten-24                 [-1, 1364]               0
#            Linear-25                  [-1, 128]         174,720
# ================================================================
# Total params: 554,450
# Trainable params: 554,450
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.18
# Forward/backward pass size (MB): 355.54
# Params size (MB): 2.12
# Estimated Total Size (MB): 357.83
# ----------------------------------------------------------------
# Total number of batches in train_loader: 781
# Epoch 1 Iteration 0: Loss = 49.663021087646484, Number of mined P N = 384 15872
# Epoch 1 Iteration 100: Loss = 41.65760040283203, Number of mined P N = 384 15872
# Epoch 1 Iteration 200: Loss = 40.52423095703125, Number of mined P N = 384 15872
# Epoch 1 Iteration 300: Loss = 38.45114517211914, Number of mined P N = 384 15872
# Epoch 1 Iteration 400: Loss = 38.56718444824219, Number of mined P N = 384 15872
# Epoch 1 Iteration 500: Loss = 39.713050842285156, Number of mined P N = 384 15872
# Epoch 1 Iteration 600: Loss = 38.63966369628906, Number of mined P N = 384 15872
# Epoch 1 Iteration 700: Loss = 37.8319091796875, Number of mined P N = 384 15872
# Validation loss:  37.9110913848877
# Total number of batches in train_loader: 781
# Epoch 2 Iteration 0: Loss = 37.877811431884766, Number of mined P N = 384 15872
# Epoch 2 Iteration 100: Loss = 38.248653411865234, Number of mined P N = 384 15872
# Epoch 2 Iteration 200: Loss = 37.57002639770508, Number of mined P N = 384 15872
# Epoch 2 Iteration 300: Loss = 37.80009078979492, Number of mined P N = 384 15872
# Epoch 2 Iteration 400: Loss = 37.35200881958008, Number of mined P N = 384 15872
# Epoch 2 Iteration 500: Loss = 37.89244842529297, Number of mined P N = 384 15872
# Epoch 2 Iteration 600: Loss = 37.720970153808594, Number of mined P N = 384 15872
# Epoch 2 Iteration 700: Loss = 37.304229736328125, Number of mined P N = 384 15872
# Validation loss:  37.218322830200194
# Total number of batches in train_loader: 781
# Epoch 3 Iteration 0: Loss = 37.69818115234375, Number of mined P N = 384 15872
# Epoch 3 Iteration 100: Loss = 37.38744354248047, Number of mined P N = 384 15872
# Epoch 3 Iteration 200: Loss = 37.35491943359375, Number of mined P N = 384 15872
# Epoch 3 Iteration 300: Loss = 37.54296112060547, Number of mined P N = 384 15872
# Epoch 3 Iteration 400: Loss = 37.2296028137207, Number of mined P N = 384 15872
# Epoch 3 Iteration 500: Loss = 37.03064727783203, Number of mined P N = 384 15872
# Epoch 3 Iteration 600: Loss = 37.492530822753906, Number of mined P N = 384 15872
# Epoch 3 Iteration 700: Loss = 37.03704833984375, Number of mined P N = 384 15872
# Validation loss:  37.01185935974121
# Total number of batches in train_loader: 781
# Epoch 4 Iteration 0: Loss = 36.99535369873047, Number of mined P N = 384 15872
# Epoch 4 Iteration 100: Loss = 36.780357360839844, Number of mined P N = 384 15872
# Epoch 4 Iteration 200: Loss = 36.515811920166016, Number of mined P N = 384 15872
# Epoch 4 Iteration 300: Loss = 36.59953689575195, Number of mined P N = 384 15872
# Epoch 4 Iteration 400: Loss = 37.43402862548828, Number of mined P N = 384 15872
# Epoch 4 Iteration 500: Loss = 36.878326416015625, Number of mined P N = 384 15872
# Epoch 4 Iteration 600: Loss = 36.74986267089844, Number of mined P N = 384 15872
# Epoch 4 Iteration 700: Loss = 36.23954772949219, Number of mined P N = 384 15872
# Validation loss:  36.86599411010742
# Total number of batches in train_loader: 781
# Epoch 5 Iteration 0: Loss = 37.52076721191406, Number of mined P N = 384 15872
# Epoch 5 Iteration 100: Loss = 37.141788482666016, Number of mined P N = 384 15872
# Epoch 5 Iteration 200: Loss = 36.956695556640625, Number of mined P N = 384 15872
# Epoch 5 Iteration 300: Loss = 36.615379333496094, Number of mined P N = 384 15872
# Epoch 5 Iteration 400: Loss = 36.58123016357422, Number of mined P N = 384 15872
# Epoch 5 Iteration 500: Loss = 36.70200729370117, Number of mined P N = 384 15872
# Epoch 5 Iteration 600: Loss = 36.79649353027344, Number of mined P N = 384 15872
# Epoch 5 Iteration 700: Loss = 37.07649612426758, Number of mined P N = 384 15872
# Validation loss:  36.83245559692383
# Total number of batches in train_loader: 781
# Epoch 6 Iteration 0: Loss = 37.143653869628906, Number of mined P N = 384 15872
# Epoch 6 Iteration 100: Loss = 37.130638122558594, Number of mined P N = 384 15872
# Epoch 6 Iteration 200: Loss = 37.07838439941406, Number of mined P N = 384 15872
# Epoch 6 Iteration 300: Loss = 36.59849548339844, Number of mined P N = 384 15872
# Epoch 6 Iteration 400: Loss = 36.34375, Number of mined P N = 384 15872
# Epoch 6 Iteration 500: Loss = 36.8097038269043, Number of mined P N = 384 15872
# Epoch 6 Iteration 600: Loss = 36.856414794921875, Number of mined P N = 384 15872
# Epoch 6 Iteration 700: Loss = 36.727149963378906, Number of mined P N = 384 15872
# Validation loss:  36.80528167724609
# Total number of batches in train_loader: 781
# Epoch 7 Iteration 0: Loss = 36.2355842590332, Number of mined P N = 384 15872
# Epoch 7 Iteration 100: Loss = 36.68309020996094, Number of mined P N = 384 15872
# Epoch 7 Iteration 200: Loss = 36.78533935546875, Number of mined P N = 384 15872
# Epoch 7 Iteration 300: Loss = 37.04644012451172, Number of mined P N = 384 15872
# Epoch 7 Iteration 400: Loss = 36.98002243041992, Number of mined P N = 384 15872
# Epoch 7 Iteration 500: Loss = 37.22679901123047, Number of mined P N = 384 15872
# Epoch 7 Iteration 600: Loss = 37.07386016845703, Number of mined P N = 384 15872
# Epoch 7 Iteration 700: Loss = 37.29964065551758, Number of mined P N = 384 15872
# Validation loss:  36.838501892089845
# Total number of batches in train_loader: 781
# Epoch 8 Iteration 0: Loss = 36.631710052490234, Number of mined P N = 384 15872
# Epoch 8 Iteration 100: Loss = 36.80928039550781, Number of mined P N = 384 15872
# Epoch 8 Iteration 200: Loss = 36.4573860168457, Number of mined P N = 384 15872
# Epoch 8 Iteration 300: Loss = 36.563636779785156, Number of mined P N = 384 15872
# Epoch 8 Iteration 400: Loss = 37.09775161743164, Number of mined P N = 384 15872
# Epoch 8 Iteration 500: Loss = 36.48973083496094, Number of mined P N = 384 15872
# Epoch 8 Iteration 600: Loss = 36.654178619384766, Number of mined P N = 384 15872
# Epoch 8 Iteration 700: Loss = 36.67560577392578, Number of mined P N = 384 15872
# Validation loss:  36.79511734008789
# Total number of batches in train_loader: 781
# Epoch 9 Iteration 0: Loss = 36.652259826660156, Number of mined P N = 384 15872
# Epoch 9 Iteration 100: Loss = 36.93177032470703, Number of mined P N = 384 15872
# Epoch 9 Iteration 200: Loss = 36.38197708129883, Number of mined P N = 384 15872
# Epoch 9 Iteration 300: Loss = 36.306640625, Number of mined P N = 384 15872
# Epoch 9 Iteration 400: Loss = 36.66697692871094, Number of mined P N = 384 15872
# Epoch 9 Iteration 500: Loss = 36.88636779785156, Number of mined P N = 384 15872
# Epoch 9 Iteration 600: Loss = 36.76339340209961, Number of mined P N = 384 15872
# Epoch 9 Iteration 700: Loss = 36.68236541748047, Number of mined P N = 384 15872
# Validation loss:  36.72338447570801
# Total number of batches in train_loader: 781
# Epoch 10 Iteration 0: Loss = 36.97294998168945, Number of mined P N = 384 15872
# Epoch 10 Iteration 100: Loss = 36.596961975097656, Number of mined P N = 384 15872
# Epoch 10 Iteration 200: Loss = 36.62791061401367, Number of mined P N = 384 15872
# Epoch 10 Iteration 300: Loss = 37.192657470703125, Number of mined P N = 384 15872
# Epoch 10 Iteration 400: Loss = 36.27293014526367, Number of mined P N = 384 15872
# Epoch 10 Iteration 500: Loss = 37.167030334472656, Number of mined P N = 384 15872
# Epoch 10 Iteration 600: Loss = 36.77194595336914, Number of mined P N = 384 15872
# Epoch 10 Iteration 700: Loss = 36.8875846862793, Number of mined P N = 384 15872
# Validation loss:  36.79084136962891
# Total number of batches in train_loader: 781
# Epoch 11 Iteration 0: Loss = 36.70649719238281, Number of mined P N = 384 15872
# Epoch 11 Iteration 100: Loss = 36.41590118408203, Number of mined P N = 384 15872
# Epoch 11 Iteration 200: Loss = 37.23952102661133, Number of mined P N = 384 15872
# Epoch 11 Iteration 300: Loss = 36.3072509765625, Number of mined P N = 384 15872
# Epoch 11 Iteration 400: Loss = 37.259765625, Number of mined P N = 384 15872
# Epoch 11 Iteration 500: Loss = 36.959712982177734, Number of mined P N = 384 15872
# Epoch 11 Iteration 600: Loss = 36.93361282348633, Number of mined P N = 384 15872
# Epoch 11 Iteration 700: Loss = 36.80499267578125, Number of mined P N = 384 15872
# Validation loss:  36.774948272705075
# Total number of batches in train_loader: 781
# Epoch 12 Iteration 0: Loss = 36.95708465576172, Number of mined P N = 384 15872
# Epoch 12 Iteration 100: Loss = 36.616878509521484, Number of mined P N = 384 15872
# Epoch 12 Iteration 200: Loss = 37.01005554199219, Number of mined P N = 384 15872
# Epoch 12 Iteration 300: Loss = 36.546600341796875, Number of mined P N = 384 15872
# Epoch 12 Iteration 400: Loss = 36.778846740722656, Number of mined P N = 384 15872
# Epoch 12 Iteration 500: Loss = 36.16255187988281, Number of mined P N = 384 15872
# Epoch 12 Iteration 600: Loss = 36.77790451049805, Number of mined P N = 384 15872
# Epoch 12 Iteration 700: Loss = 36.635398864746094, Number of mined P N = 384 15872
# Validation loss:  36.746897583007815
# Total number of batches in train_loader: 781
# Epoch 13 Iteration 0: Loss = 36.48297882080078, Number of mined P N = 384 15872
# Epoch 13 Iteration 100: Loss = 36.544742584228516, Number of mined P N = 384 15872
# Epoch 13 Iteration 200: Loss = 37.00736618041992, Number of mined P N = 384 15872
# Epoch 13 Iteration 300: Loss = 36.332733154296875, Number of mined P N = 384 15872
# Epoch 13 Iteration 400: Loss = 36.81585693359375, Number of mined P N = 384 15872
# Epoch 13 Iteration 500: Loss = 37.27691650390625, Number of mined P N = 384 15872
# Epoch 13 Iteration 600: Loss = 36.34033203125, Number of mined P N = 384 15872
# Epoch 13 Iteration 700: Loss = 36.446937561035156, Number of mined P N = 384 15872
# Validation loss:  36.762613220214845
# Total number of batches in train_loader: 781
# Epoch 14 Iteration 0: Loss = 37.039878845214844, Number of mined P N = 384 15872
# Epoch 14 Iteration 100: Loss = 37.00621032714844, Number of mined P N = 384 15872
# Epoch 14 Iteration 200: Loss = 36.947364807128906, Number of mined P N = 384 15872
# Epoch 14 Iteration 300: Loss = 36.83368682861328, Number of mined P N = 384 15872
# Epoch 14 Iteration 400: Loss = 37.15312576293945, Number of mined P N = 384 15872
# Epoch 14 Iteration 500: Loss = 36.08332061767578, Number of mined P N = 384 15872
# Epoch 14 Iteration 600: Loss = 36.904884338378906, Number of mined P N = 384 15872
# Epoch 14 Iteration 700: Loss = 36.71116638183594, Number of mined P N = 384 15872
# Validation loss:  36.74040802001953
# Total number of batches in train_loader: 781
# Epoch 15 Iteration 0: Loss = 37.01299285888672, Number of mined P N = 384 15872
# Epoch 15 Iteration 100: Loss = 36.46472930908203, Number of mined P N = 384 15872
# Epoch 15 Iteration 200: Loss = 36.36408233642578, Number of mined P N = 384 15872
# Epoch 15 Iteration 300: Loss = 36.99840545654297, Number of mined P N = 384 15872
# Epoch 15 Iteration 400: Loss = 36.428688049316406, Number of mined P N = 384 15872
# Epoch 15 Iteration 500: Loss = 36.998069763183594, Number of mined P N = 384 15872
# Epoch 15 Iteration 600: Loss = 36.839210510253906, Number of mined P N = 384 15872
# Epoch 15 Iteration 700: Loss = 36.558433532714844, Number of mined P N = 384 15872
# Validation loss:  36.74961151123047
# Total number of batches in train_loader: 781
# Epoch 16 Iteration 0: Loss = 36.815826416015625, Number of mined P N = 384 15872
# Epoch 16 Iteration 100: Loss = 36.77526092529297, Number of mined P N = 384 15872
# Epoch 16 Iteration 200: Loss = 37.03877639770508, Number of mined P N = 384 15872
# Epoch 16 Iteration 300: Loss = 37.19756317138672, Number of mined P N = 384 15872
# Epoch 16 Iteration 400: Loss = 36.714637756347656, Number of mined P N = 384 15872
# Epoch 16 Iteration 500: Loss = 36.51762390136719, Number of mined P N = 384 15872
# Epoch 16 Iteration 600: Loss = 36.416961669921875, Number of mined P N = 384 15872
# Epoch 16 Iteration 700: Loss = 36.84349060058594, Number of mined P N = 384 15872
# Validation loss:  36.75707267761231
# Total number of batches in train_loader: 781
# Epoch 17 Iteration 0: Loss = 37.16468811035156, Number of mined P N = 384 15872
# Epoch 17 Iteration 100: Loss = 36.91120147705078, Number of mined P N = 384 15872
# Epoch 17 Iteration 200: Loss = 36.59562301635742, Number of mined P N = 384 15872
# Epoch 17 Iteration 300: Loss = 36.737003326416016, Number of mined P N = 384 15872
# Epoch 17 Iteration 400: Loss = 36.19519805908203, Number of mined P N = 384 15872
# Epoch 17 Iteration 500: Loss = 36.139915466308594, Number of mined P N = 384 15872
# Epoch 17 Iteration 600: Loss = 36.57059860229492, Number of mined P N = 384 15872
# Epoch 17 Iteration 700: Loss = 36.457664489746094, Number of mined P N = 384 15872
# Validation loss:  36.68867988586426
# Total number of batches in train_loader: 781
# Epoch 18 Iteration 0: Loss = 36.517181396484375, Number of mined P N = 384 15872
# Epoch 18 Iteration 100: Loss = 36.950077056884766, Number of mined P N = 384 15872
# Epoch 18 Iteration 200: Loss = 36.48080825805664, Number of mined P N = 384 15872
# Epoch 18 Iteration 300: Loss = 36.26081848144531, Number of mined P N = 384 15872
# Epoch 18 Iteration 400: Loss = 36.50828552246094, Number of mined P N = 384 15872
# Epoch 18 Iteration 500: Loss = 36.39399337768555, Number of mined P N = 384 15872
# Epoch 18 Iteration 600: Loss = 36.12163543701172, Number of mined P N = 384 15872
# Epoch 18 Iteration 700: Loss = 36.58911895751953, Number of mined P N = 384 15872
# Validation loss:  36.70527519226074
# Total number of batches in train_loader: 781
# Epoch 19 Iteration 0: Loss = 36.996917724609375, Number of mined P N = 384 15872
# Epoch 19 Iteration 100: Loss = 36.59336853027344, Number of mined P N = 384 15872
# Epoch 19 Iteration 200: Loss = 36.57082748413086, Number of mined P N = 384 15872
# Epoch 19 Iteration 300: Loss = 36.579872131347656, Number of mined P N = 384 15872
# Epoch 19 Iteration 400: Loss = 36.92453384399414, Number of mined P N = 384 15872
# Epoch 19 Iteration 500: Loss = 36.86671447753906, Number of mined P N = 384 15872
# Epoch 19 Iteration 600: Loss = 36.62730407714844, Number of mined P N = 384 15872
# Epoch 19 Iteration 700: Loss = 36.750343322753906, Number of mined P N = 384 15872
# Validation loss:  36.760435333251955
# Total number of batches in train_loader: 781
# Epoch 20 Iteration 0: Loss = 36.480812072753906, Number of mined P N = 384 15872
# Epoch 20 Iteration 100: Loss = 36.64649963378906, Number of mined P N = 384 15872
# Epoch 20 Iteration 200: Loss = 36.708961486816406, Number of mined P N = 384 15872
# Epoch 20 Iteration 300: Loss = 36.76994323730469, Number of mined P N = 384 15872
# Epoch 20 Iteration 400: Loss = 36.564937591552734, Number of mined P N = 384 15872
# Epoch 20 Iteration 500: Loss = 36.965965270996094, Number of mined P N = 384 15872
# Epoch 20 Iteration 600: Loss = 36.36931610107422, Number of mined P N = 384 15872
# Epoch 20 Iteration 700: Loss = 36.79155731201172, Number of mined P N = 384 15872
# Validation loss:  36.740526580810545
# Total number of batches in train_loader: 781
# Epoch 21 Iteration 0: Loss = 36.809349060058594, Number of mined P N = 384 15872
# Epoch 21 Iteration 100: Loss = 36.850852966308594, Number of mined P N = 384 15872
# Epoch 21 Iteration 200: Loss = 37.22512435913086, Number of mined P N = 384 15872
# Epoch 21 Iteration 300: Loss = 36.668365478515625, Number of mined P N = 384 15872
# Epoch 21 Iteration 400: Loss = 36.7614631652832, Number of mined P N = 384 15872
# Epoch 21 Iteration 500: Loss = 36.66360855102539, Number of mined P N = 384 15872
# Epoch 21 Iteration 600: Loss = 36.46873092651367, Number of mined P N = 384 15872
# Epoch 21 Iteration 700: Loss = 36.655799865722656, Number of mined P N = 384 15872
# Validation loss:  36.719879913330075
# Total number of batches in train_loader: 781
# Epoch 22 Iteration 0: Loss = 36.67504119873047, Number of mined P N = 384 15872
# Epoch 22 Iteration 100: Loss = 36.63258361816406, Number of mined P N = 384 15872
# Epoch 22 Iteration 200: Loss = 36.39959716796875, Number of mined P N = 384 15872
# Epoch 22 Iteration 300: Loss = 36.72826385498047, Number of mined P N = 384 15872
# Epoch 22 Iteration 400: Loss = 36.45442199707031, Number of mined P N = 384 15872
# Epoch 22 Iteration 500: Loss = 36.81060028076172, Number of mined P N = 384 15872
# Epoch 22 Iteration 600: Loss = 36.67851638793945, Number of mined P N = 384 15872
# Epoch 22 Iteration 700: Loss = 36.53214645385742, Number of mined P N = 384 15872
# Validation loss:  36.71446014404297
# Total number of batches in train_loader: 781
# Epoch 23 Iteration 0: Loss = 36.513118743896484, Number of mined P N = 384 15872
# Epoch 23 Iteration 100: Loss = 36.53839111328125, Number of mined P N = 384 15872
# Epoch 23 Iteration 200: Loss = 37.198081970214844, Number of mined P N = 384 15872
# Epoch 23 Iteration 300: Loss = 36.24068832397461, Number of mined P N = 384 15872
# Epoch 23 Iteration 400: Loss = 36.78721237182617, Number of mined P N = 384 15872
# Epoch 23 Iteration 500: Loss = 36.87928771972656, Number of mined P N = 384 15872
# Epoch 23 Iteration 600: Loss = 37.033607482910156, Number of mined P N = 384 15872
# Epoch 23 Iteration 700: Loss = 36.382022857666016, Number of mined P N = 384 15872
# Validation loss:  36.80879173278809
# Total number of batches in train_loader: 781
# Epoch 24 Iteration 0: Loss = 36.15129470825195, Number of mined P N = 384 15872
# Epoch 24 Iteration 100: Loss = 36.41828155517578, Number of mined P N = 384 15872
# Epoch 24 Iteration 200: Loss = 36.87457275390625, Number of mined P N = 384 15872
# Epoch 24 Iteration 300: Loss = 36.57219314575195, Number of mined P N = 384 15872
# Epoch 24 Iteration 400: Loss = 36.718292236328125, Number of mined P N = 384 15872
# Epoch 24 Iteration 500: Loss = 37.13654327392578, Number of mined P N = 384 15872
# Epoch 24 Iteration 600: Loss = 36.97430419921875, Number of mined P N = 384 15872
# Epoch 24 Iteration 700: Loss = 36.84378433227539, Number of mined P N = 384 15872
# Validation loss:  36.63557640075683
# Total number of batches in train_loader: 781
# Epoch 25 Iteration 0: Loss = 36.87540054321289, Number of mined P N = 384 15872
# Epoch 25 Iteration 100: Loss = 36.58625793457031, Number of mined P N = 384 15872
# Epoch 25 Iteration 200: Loss = 36.469871520996094, Number of mined P N = 384 15872
# Epoch 25 Iteration 300: Loss = 36.34885787963867, Number of mined P N = 384 15872
# Epoch 25 Iteration 400: Loss = 36.76055908203125, Number of mined P N = 384 15872
# Epoch 25 Iteration 500: Loss = 37.29965591430664, Number of mined P N = 384 15872
# Epoch 25 Iteration 600: Loss = 36.67002868652344, Number of mined P N = 384 15872
# Epoch 25 Iteration 700: Loss = 37.1483039855957, Number of mined P N = 384 15872
# Validation loss:  36.78196891784668
# Total number of batches in train_loader: 781
# Epoch 26 Iteration 0: Loss = 36.472225189208984, Number of mined P N = 384 15872
# Epoch 26 Iteration 100: Loss = 36.57210159301758, Number of mined P N = 384 15872
# Epoch 26 Iteration 200: Loss = 36.49641036987305, Number of mined P N = 384 15872
# Epoch 26 Iteration 300: Loss = 36.76139831542969, Number of mined P N = 384 15872
# Epoch 26 Iteration 400: Loss = 36.43840789794922, Number of mined P N = 384 15872
# Epoch 26 Iteration 500: Loss = 36.444541931152344, Number of mined P N = 384 15872
# Epoch 26 Iteration 600: Loss = 36.09709930419922, Number of mined P N = 384 15872
# Epoch 26 Iteration 700: Loss = 36.895931243896484, Number of mined P N = 384 15872
# Validation loss:  36.70925712585449
# Total number of batches in train_loader: 781
# Epoch 27 Iteration 0: Loss = 36.195281982421875, Number of mined P N = 384 15872
# Epoch 27 Iteration 100: Loss = 36.941436767578125, Number of mined P N = 384 15872
# Epoch 27 Iteration 200: Loss = 36.866859436035156, Number of mined P N = 384 15872
# Epoch 27 Iteration 300: Loss = 37.07030487060547, Number of mined P N = 384 15872
# Epoch 27 Iteration 400: Loss = 36.954750061035156, Number of mined P N = 384 15872
# Epoch 27 Iteration 500: Loss = 37.198768615722656, Number of mined P N = 384 15872
# Epoch 27 Iteration 600: Loss = 36.945594787597656, Number of mined P N = 384 15872
# Epoch 27 Iteration 700: Loss = 36.425113677978516, Number of mined P N = 384 15872
# Validation loss:  36.66395767211914
# Total number of batches in train_loader: 781
# Epoch 28 Iteration 0: Loss = 37.1368293762207, Number of mined P N = 384 15872
# Epoch 28 Iteration 100: Loss = 36.77757263183594, Number of mined P N = 384 15872
# Epoch 28 Iteration 200: Loss = 36.82868576049805, Number of mined P N = 384 15872
# Epoch 28 Iteration 300: Loss = 36.43732833862305, Number of mined P N = 384 15872
# Epoch 28 Iteration 400: Loss = 36.69690704345703, Number of mined P N = 384 15872
# Epoch 28 Iteration 500: Loss = 36.625953674316406, Number of mined P N = 384 15872
# Epoch 28 Iteration 600: Loss = 36.79119873046875, Number of mined P N = 384 15872
# Epoch 28 Iteration 700: Loss = 36.74524688720703, Number of mined P N = 384 15872
# Validation loss:  36.73058822631836
# Total number of batches in train_loader: 781
# Epoch 29 Iteration 0: Loss = 36.32029724121094, Number of mined P N = 384 15872
# Epoch 29 Iteration 100: Loss = 36.77485656738281, Number of mined P N = 384 15872
# Epoch 29 Iteration 200: Loss = 36.49332046508789, Number of mined P N = 384 15872
# Epoch 29 Iteration 300: Loss = 36.72388458251953, Number of mined P N = 384 15872
# Epoch 29 Iteration 400: Loss = 37.262916564941406, Number of mined P N = 384 15872
# Epoch 29 Iteration 500: Loss = 36.893375396728516, Number of mined P N = 384 15872
# Epoch 29 Iteration 600: Loss = 36.697601318359375, Number of mined P N = 384 15872
# Epoch 29 Iteration 700: Loss = 36.93779754638672, Number of mined P N = 384 15872
# Validation loss:  36.70920623779297
# Total number of batches in train_loader: 781
# Epoch 30 Iteration 0: Loss = 37.509971618652344, Number of mined P N = 384 15872
# Epoch 30 Iteration 100: Loss = 37.42692565917969, Number of mined P N = 384 15872
# Epoch 30 Iteration 200: Loss = 37.113014221191406, Number of mined P N = 384 15872
# Epoch 30 Iteration 300: Loss = 36.98846435546875, Number of mined P N = 384 15872
# Epoch 30 Iteration 400: Loss = 37.00170135498047, Number of mined P N = 384 15872
# Epoch 30 Iteration 500: Loss = 36.32847595214844, Number of mined P N = 384 15872
# Epoch 30 Iteration 600: Loss = 36.69425964355469, Number of mined P N = 384 15872
# Epoch 30 Iteration 700: Loss = 36.045509338378906, Number of mined P N = 384 15872
# Validation loss:  36.720963897705076
# Total number of batches in train_loader: 781
# Epoch 31 Iteration 0: Loss = 36.78159713745117, Number of mined P N = 384 15872
# Epoch 31 Iteration 100: Loss = 36.612953186035156, Number of mined P N = 384 15872
# Epoch 31 Iteration 200: Loss = 36.79443359375, Number of mined P N = 384 15872
# Epoch 31 Iteration 300: Loss = 36.80134963989258, Number of mined P N = 384 15872
# Epoch 31 Iteration 400: Loss = 36.46967315673828, Number of mined P N = 384 15872
# Epoch 31 Iteration 500: Loss = 36.57276153564453, Number of mined P N = 384 15872
# Epoch 31 Iteration 600: Loss = 36.325469970703125, Number of mined P N = 384 15872
# Epoch 31 Iteration 700: Loss = 36.48575210571289, Number of mined P N = 384 15872
# Validation loss:  36.74067626953125
# Total number of batches in train_loader: 781
# Epoch 32 Iteration 0: Loss = 36.59453201293945, Number of mined P N = 384 15872
# Epoch 32 Iteration 100: Loss = 36.58905029296875, Number of mined P N = 384 15872
# Epoch 32 Iteration 200: Loss = 36.25580596923828, Number of mined P N = 384 15872
# Epoch 32 Iteration 300: Loss = 36.807987213134766, Number of mined P N = 384 15872
# Epoch 32 Iteration 400: Loss = 37.04343032836914, Number of mined P N = 384 15872
# Epoch 32 Iteration 500: Loss = 36.44431686401367, Number of mined P N = 384 15872
# Epoch 32 Iteration 600: Loss = 36.71240234375, Number of mined P N = 384 15872
# Epoch 32 Iteration 700: Loss = 36.643341064453125, Number of mined P N = 384 15872
# Validation loss:  36.72379722595215
# Total number of batches in train_loader: 781
# Epoch 33 Iteration 0: Loss = 36.467830657958984, Number of mined P N = 384 15872
# Epoch 33 Iteration 100: Loss = 37.436676025390625, Number of mined P N = 384 15872
# Epoch 33 Iteration 200: Loss = 36.54302215576172, Number of mined P N = 384 15872
# Epoch 33 Iteration 300: Loss = 36.607269287109375, Number of mined P N = 384 15872
# Epoch 33 Iteration 400: Loss = 36.44065856933594, Number of mined P N = 384 15872
# Epoch 33 Iteration 500: Loss = 36.39575958251953, Number of mined P N = 384 15872
# Epoch 33 Iteration 600: Loss = 36.642616271972656, Number of mined P N = 384 15872
# Epoch 33 Iteration 700: Loss = 36.383304595947266, Number of mined P N = 384 15872
# Validation loss:  36.74573226928711
# Total number of batches in train_loader: 781
# Epoch 34 Iteration 0: Loss = 36.55949783325195, Number of mined P N = 384 15872
# Epoch 34 Iteration 100: Loss = 36.758853912353516, Number of mined P N = 384 15872
# Epoch 34 Iteration 200: Loss = 36.37238311767578, Number of mined P N = 384 15872
# Epoch 34 Iteration 300: Loss = 36.65263366699219, Number of mined P N = 384 15872
# Epoch 34 Iteration 400: Loss = 36.80086135864258, Number of mined P N = 384 15872
# Epoch 34 Iteration 500: Loss = 36.66672897338867, Number of mined P N = 384 15872
# Epoch 34 Iteration 600: Loss = 36.28083038330078, Number of mined P N = 384 15872
# Epoch 34 Iteration 700: Loss = 36.96315002441406, Number of mined P N = 384 15872
# Validation loss:  36.76955345153809
# Total number of batches in train_loader: 781
# Epoch 35 Iteration 0: Loss = 36.954811096191406, Number of mined P N = 384 15872
# Epoch 35 Iteration 100: Loss = 36.82577896118164, Number of mined P N = 384 15872
# Epoch 35 Iteration 200: Loss = 36.738990783691406, Number of mined P N = 384 15872
# Epoch 35 Iteration 300: Loss = 37.01740264892578, Number of mined P N = 384 15872
# Epoch 35 Iteration 400: Loss = 36.44429016113281, Number of mined P N = 384 15872
# Epoch 35 Iteration 500: Loss = 36.67350387573242, Number of mined P N = 384 15872
# Epoch 35 Iteration 600: Loss = 36.258487701416016, Number of mined P N = 384 15872
# Epoch 35 Iteration 700: Loss = 36.64373016357422, Number of mined P N = 384 15872
# Validation loss:  36.642170944213866
# Total number of batches in train_loader: 781
# Epoch 36 Iteration 0: Loss = 36.84501647949219, Number of mined P N = 384 15872
# Epoch 36 Iteration 100: Loss = 36.863983154296875, Number of mined P N = 384 15872
# Epoch 36 Iteration 200: Loss = 36.93238830566406, Number of mined P N = 384 15872
# Epoch 36 Iteration 300: Loss = 36.70746612548828, Number of mined P N = 384 15872
# Epoch 36 Iteration 400: Loss = 36.59839630126953, Number of mined P N = 384 15872
# Epoch 36 Iteration 500: Loss = 36.47755432128906, Number of mined P N = 384 15872
# Epoch 36 Iteration 600: Loss = 36.877647399902344, Number of mined P N = 384 15872
# Epoch 36 Iteration 700: Loss = 36.58942413330078, Number of mined P N = 384 15872
# Validation loss:  36.6971492767334
# Total number of batches in train_loader: 781
# Epoch 37 Iteration 0: Loss = 37.07952880859375, Number of mined P N = 384 15872
# Epoch 37 Iteration 100: Loss = 36.62629699707031, Number of mined P N = 384 15872
# Epoch 37 Iteration 200: Loss = 36.408782958984375, Number of mined P N = 384 15872
# Epoch 37 Iteration 300: Loss = 36.45517349243164, Number of mined P N = 384 15872
# Epoch 37 Iteration 400: Loss = 36.763145446777344, Number of mined P N = 384 15872
# Epoch 37 Iteration 500: Loss = 37.152740478515625, Number of mined P N = 384 15872
# Epoch 37 Iteration 600: Loss = 36.15498733520508, Number of mined P N = 384 15872
# Epoch 37 Iteration 700: Loss = 36.45503234863281, Number of mined P N = 384 15872
# Validation loss:  36.64808204650879
# Total number of batches in train_loader: 781
# Epoch 38 Iteration 0: Loss = 36.694541931152344, Number of mined P N = 384 15872
# Epoch 38 Iteration 100: Loss = 36.81005096435547, Number of mined P N = 384 15872
# Epoch 38 Iteration 200: Loss = 36.583465576171875, Number of mined P N = 384 15872
# Epoch 38 Iteration 300: Loss = 36.47494888305664, Number of mined P N = 384 15872
# Epoch 38 Iteration 400: Loss = 36.73550033569336, Number of mined P N = 384 15872
# Epoch 38 Iteration 500: Loss = 36.879600524902344, Number of mined P N = 384 15872
# Epoch 38 Iteration 600: Loss = 36.60795211791992, Number of mined P N = 384 15872
# Epoch 38 Iteration 700: Loss = 36.196800231933594, Number of mined P N = 384 15872
# Validation loss:  36.66429321289063
# Total number of batches in train_loader: 781
# Epoch 39 Iteration 0: Loss = 37.11610412597656, Number of mined P N = 384 15872
# Epoch 39 Iteration 100: Loss = 36.83550262451172, Number of mined P N = 384 15872
# Epoch 39 Iteration 200: Loss = 36.48274612426758, Number of mined P N = 384 15872
# Epoch 39 Iteration 300: Loss = 36.50875473022461, Number of mined P N = 384 15872
# Epoch 39 Iteration 400: Loss = 36.18748474121094, Number of mined P N = 384 15872
# Epoch 39 Iteration 500: Loss = 36.864620208740234, Number of mined P N = 384 15872
# Epoch 39 Iteration 600: Loss = 36.46071243286133, Number of mined P N = 384 15872
# Epoch 39 Iteration 700: Loss = 36.52530288696289, Number of mined P N = 384 15872
# Validation loss:  36.674447555541995
# Total number of batches in train_loader: 781
# Epoch 40 Iteration 0: Loss = 36.41464614868164, Number of mined P N = 384 15872
# Epoch 40 Iteration 100: Loss = 36.704978942871094, Number of mined P N = 384 15872
# Epoch 40 Iteration 200: Loss = 36.36573791503906, Number of mined P N = 384 15872
# Epoch 40 Iteration 300: Loss = 36.66053771972656, Number of mined P N = 384 15872
# Epoch 40 Iteration 400: Loss = 36.26352310180664, Number of mined P N = 384 15872
# Epoch 40 Iteration 500: Loss = 36.8984375, Number of mined P N = 384 15872
# Epoch 40 Iteration 600: Loss = 36.491268157958984, Number of mined P N = 384 15872
# Epoch 40 Iteration 700: Loss = 36.64207077026367, Number of mined P N = 384 15872
# Validation loss:  36.71342170715332
# Total number of batches in train_loader: 781
# Epoch 41 Iteration 0: Loss = 36.66438674926758, Number of mined P N = 384 15872
# Epoch 41 Iteration 100: Loss = 36.909393310546875, Number of mined P N = 384 15872
# Epoch 41 Iteration 200: Loss = 36.794036865234375, Number of mined P N = 384 15872
# Epoch 41 Iteration 300: Loss = 36.11468505859375, Number of mined P N = 384 15872
# Epoch 41 Iteration 400: Loss = 36.549346923828125, Number of mined P N = 384 15872
# Epoch 41 Iteration 500: Loss = 36.674808502197266, Number of mined P N = 384 15872
# Epoch 41 Iteration 600: Loss = 36.083641052246094, Number of mined P N = 384 15872
# Epoch 41 Iteration 700: Loss = 36.83704376220703, Number of mined P N = 384 15872
# Validation loss:  36.726818618774416
# Total number of batches in train_loader: 781
# Epoch 42 Iteration 0: Loss = 36.29832458496094, Number of mined P N = 384 15872
# Epoch 42 Iteration 100: Loss = 36.593780517578125, Number of mined P N = 384 15872
# Epoch 42 Iteration 200: Loss = 36.48109436035156, Number of mined P N = 384 15872
# Epoch 42 Iteration 300: Loss = 36.83380889892578, Number of mined P N = 384 15872
# Epoch 42 Iteration 400: Loss = 36.7087516784668, Number of mined P N = 384 15872
# Epoch 42 Iteration 500: Loss = 36.5616455078125, Number of mined P N = 384 15872
# Epoch 42 Iteration 600: Loss = 36.93124771118164, Number of mined P N = 384 15872
# Epoch 42 Iteration 700: Loss = 36.84011459350586, Number of mined P N = 384 15872
# Validation loss:  36.8211939239502
# Total number of batches in train_loader: 781
# Epoch 43 Iteration 0: Loss = 37.50320816040039, Number of mined P N = 384 15872
# Epoch 43 Iteration 100: Loss = 36.32686996459961, Number of mined P N = 384 15872
# Epoch 43 Iteration 200: Loss = 36.58125305175781, Number of mined P N = 384 15872
# Epoch 43 Iteration 300: Loss = 36.538047790527344, Number of mined P N = 384 15872
# Epoch 43 Iteration 400: Loss = 36.95600891113281, Number of mined P N = 384 15872
# Epoch 43 Iteration 500: Loss = 36.70142364501953, Number of mined P N = 384 15872
# Epoch 43 Iteration 600: Loss = 36.44190979003906, Number of mined P N = 384 15872
# Epoch 43 Iteration 700: Loss = 36.69945526123047, Number of mined P N = 384 15872
# Validation loss:  36.64441993713379
# Total number of batches in train_loader: 781
# Epoch 44 Iteration 0: Loss = 36.50788116455078, Number of mined P N = 384 15872
# Epoch 44 Iteration 100: Loss = 36.835426330566406, Number of mined P N = 384 15872
# Epoch 44 Iteration 200: Loss = 36.80451583862305, Number of mined P N = 384 15872
# Epoch 44 Iteration 300: Loss = 36.802734375, Number of mined P N = 384 15872
# Epoch 44 Iteration 400: Loss = 36.922462463378906, Number of mined P N = 384 15872
# Epoch 44 Iteration 500: Loss = 36.569091796875, Number of mined P N = 384 15872
# Epoch 44 Iteration 600: Loss = 36.371795654296875, Number of mined P N = 384 15872
# Epoch 44 Iteration 700: Loss = 36.95520782470703, Number of mined P N = 384 15872
# Validation loss:  36.686321334838865
# Total number of batches in train_loader: 781
# Epoch 45 Iteration 0: Loss = 37.248863220214844, Number of mined P N = 384 15872
# Epoch 45 Iteration 100: Loss = 36.687347412109375, Number of mined P N = 384 15872
# Epoch 45 Iteration 200: Loss = 36.65610122680664, Number of mined P N = 384 15872
# Epoch 45 Iteration 300: Loss = 36.49285888671875, Number of mined P N = 384 15872
# Epoch 45 Iteration 400: Loss = 36.33747100830078, Number of mined P N = 384 15872
# Epoch 45 Iteration 500: Loss = 36.83580780029297, Number of mined P N = 384 15872
# Epoch 45 Iteration 600: Loss = 36.33014678955078, Number of mined P N = 384 15872
# Epoch 45 Iteration 700: Loss = 36.39073181152344, Number of mined P N = 384 15872
# Validation loss:  36.700641555786135
# Total number of batches in train_loader: 781
# Epoch 46 Iteration 0: Loss = 36.588134765625, Number of mined P N = 384 15872
# Epoch 46 Iteration 100: Loss = 36.83206558227539, Number of mined P N = 384 15872
# Epoch 46 Iteration 200: Loss = 36.978363037109375, Number of mined P N = 384 15872
# Epoch 46 Iteration 300: Loss = 36.51863098144531, Number of mined P N = 384 15872
# Epoch 46 Iteration 400: Loss = 36.497413635253906, Number of mined P N = 384 15872
# Epoch 46 Iteration 500: Loss = 36.88538360595703, Number of mined P N = 384 15872
# Epoch 46 Iteration 600: Loss = 37.681785583496094, Number of mined P N = 384 15872
# Epoch 46 Iteration 700: Loss = 36.51982879638672, Number of mined P N = 384 15872
# Validation loss:  36.70519569396973
# Total number of batches in train_loader: 781
# Epoch 47 Iteration 0: Loss = 36.73029708862305, Number of mined P N = 384 15872
# Epoch 47 Iteration 100: Loss = 36.52815246582031, Number of mined P N = 384 15872
# Epoch 47 Iteration 200: Loss = 36.52632141113281, Number of mined P N = 384 15872
# Epoch 47 Iteration 300: Loss = 36.820594787597656, Number of mined P N = 384 15872
# Epoch 47 Iteration 400: Loss = 36.81944274902344, Number of mined P N = 384 15872
# Epoch 47 Iteration 500: Loss = 36.252601623535156, Number of mined P N = 384 15872
# Epoch 47 Iteration 600: Loss = 36.78975296020508, Number of mined P N = 384 15872
# Epoch 47 Iteration 700: Loss = 36.654754638671875, Number of mined P N = 384 15872
# Validation loss:  36.586240234375
# Total number of batches in train_loader: 781
# Epoch 48 Iteration 0: Loss = 36.54804611206055, Number of mined P N = 384 15872
# Epoch 48 Iteration 100: Loss = 36.63066864013672, Number of mined P N = 384 15872
# Epoch 48 Iteration 200: Loss = 36.78767013549805, Number of mined P N = 384 15872
# Epoch 48 Iteration 300: Loss = 36.633853912353516, Number of mined P N = 384 15872
# Epoch 48 Iteration 400: Loss = 37.20226287841797, Number of mined P N = 384 15872
# Epoch 48 Iteration 500: Loss = 36.74781799316406, Number of mined P N = 384 15872
# Epoch 48 Iteration 600: Loss = 36.9923095703125, Number of mined P N = 384 15872
# Epoch 48 Iteration 700: Loss = 36.49692916870117, Number of mined P N = 384 15872
# Validation loss:  36.680210494995116
# Total number of batches in train_loader: 781
# Epoch 49 Iteration 0: Loss = 37.133541107177734, Number of mined P N = 384 15872
# Epoch 49 Iteration 100: Loss = 36.56756591796875, Number of mined P N = 384 15872
# Epoch 49 Iteration 200: Loss = 36.44728088378906, Number of mined P N = 384 15872
# Epoch 49 Iteration 300: Loss = 37.38205337524414, Number of mined P N = 384 15872
# Epoch 49 Iteration 400: Loss = 37.114830017089844, Number of mined P N = 384 15872
# Epoch 49 Iteration 500: Loss = 36.517433166503906, Number of mined P N = 384 15872
# Epoch 49 Iteration 600: Loss = 36.40167999267578, Number of mined P N = 384 15872
# Epoch 49 Iteration 700: Loss = 36.45454788208008, Number of mined P N = 384 15872
# Validation loss:  36.65985679626465
# Total number of batches in train_loader: 781
# Epoch 50 Iteration 0: Loss = 36.79642105102539, Number of mined P N = 384 15872
# Epoch 50 Iteration 100: Loss = 36.227928161621094, Number of mined P N = 384 15872
# Epoch 50 Iteration 200: Loss = 36.27725601196289, Number of mined P N = 384 15872
# Epoch 50 Iteration 300: Loss = 36.67070007324219, Number of mined P N = 384 15872
# Epoch 50 Iteration 400: Loss = 36.484439849853516, Number of mined P N = 384 15872
# Epoch 50 Iteration 500: Loss = 37.18013000488281, Number of mined P N = 384 15872
# Epoch 50 Iteration 600: Loss = 36.75874328613281, Number of mined P N = 384 15872
# Epoch 50 Iteration 700: Loss = 36.52189636230469, Number of mined P N = 384 15872
# Validation loss:  36.70412796020508
# Total number of batches in train_loader: 781
# Epoch 51 Iteration 0: Loss = 36.75509262084961, Number of mined P N = 384 15872
# Epoch 51 Iteration 100: Loss = 37.35844421386719, Number of mined P N = 384 15872
# Epoch 51 Iteration 200: Loss = 36.37822723388672, Number of mined P N = 384 15872
# Epoch 51 Iteration 300: Loss = 37.61834716796875, Number of mined P N = 384 15872
# Epoch 51 Iteration 400: Loss = 36.60374450683594, Number of mined P N = 384 15872
# Epoch 51 Iteration 500: Loss = 36.79815673828125, Number of mined P N = 384 15872
# Epoch 51 Iteration 600: Loss = 36.90707015991211, Number of mined P N = 384 15872
# Epoch 51 Iteration 700: Loss = 36.383811950683594, Number of mined P N = 384 15872
# Validation loss:  36.69693473815918
# Total number of batches in train_loader: 781
# Epoch 52 Iteration 0: Loss = 36.56812286376953, Number of mined P N = 384 15872
# Epoch 52 Iteration 100: Loss = 36.437713623046875, Number of mined P N = 384 15872
# Epoch 52 Iteration 200: Loss = 37.295204162597656, Number of mined P N = 384 15872
# Epoch 52 Iteration 300: Loss = 36.91946029663086, Number of mined P N = 384 15872
# Epoch 52 Iteration 400: Loss = 36.690982818603516, Number of mined P N = 384 15872
# Epoch 52 Iteration 500: Loss = 36.525535583496094, Number of mined P N = 384 15872
# Epoch 52 Iteration 600: Loss = 37.46043395996094, Number of mined P N = 384 15872
# Epoch 52 Iteration 700: Loss = 36.23849105834961, Number of mined P N = 384 15872
# Validation loss:  36.61397605895996
# Total number of batches in train_loader: 781
# Epoch 53 Iteration 0: Loss = 37.1298828125, Number of mined P N = 384 15872
# Epoch 53 Iteration 100: Loss = 36.66221618652344, Number of mined P N = 384 15872
# Epoch 53 Iteration 200: Loss = 36.73173522949219, Number of mined P N = 384 15872
# Epoch 53 Iteration 300: Loss = 36.713096618652344, Number of mined P N = 384 15872
# Epoch 53 Iteration 400: Loss = 36.94831848144531, Number of mined P N = 384 15872
# Epoch 53 Iteration 500: Loss = 36.374813079833984, Number of mined P N = 384 15872
# Epoch 53 Iteration 600: Loss = 36.77005386352539, Number of mined P N = 384 15872
# Epoch 53 Iteration 700: Loss = 36.36247253417969, Number of mined P N = 384 15872
# Validation loss:  36.753353881835935
# Total number of batches in train_loader: 781
# Epoch 54 Iteration 0: Loss = 36.84767150878906, Number of mined P N = 384 15872
# Epoch 54 Iteration 100: Loss = 36.287086486816406, Number of mined P N = 384 15872
# Epoch 54 Iteration 200: Loss = 36.38199996948242, Number of mined P N = 384 15872
# Epoch 54 Iteration 300: Loss = 36.197914123535156, Number of mined P N = 384 15872
# Epoch 54 Iteration 400: Loss = 36.833717346191406, Number of mined P N = 384 15872
# Epoch 54 Iteration 500: Loss = 36.806480407714844, Number of mined P N = 384 15872
# Epoch 54 Iteration 600: Loss = 37.037681579589844, Number of mined P N = 384 15872
# Epoch 54 Iteration 700: Loss = 36.36153030395508, Number of mined P N = 384 15872
# Validation loss:  36.72585388183594
# Total number of batches in train_loader: 781
# Epoch 55 Iteration 0: Loss = 36.507625579833984, Number of mined P N = 384 15872
# Epoch 55 Iteration 100: Loss = 36.84342956542969, Number of mined P N = 384 15872
# Epoch 55 Iteration 200: Loss = 36.71909713745117, Number of mined P N = 384 15872
# Epoch 55 Iteration 300: Loss = 36.382225036621094, Number of mined P N = 384 15872
# Epoch 55 Iteration 400: Loss = 36.479103088378906, Number of mined P N = 384 15872
# Epoch 55 Iteration 500: Loss = 36.991615295410156, Number of mined P N = 384 15872
# Epoch 55 Iteration 600: Loss = 36.36772918701172, Number of mined P N = 384 15872
# Epoch 55 Iteration 700: Loss = 36.52307891845703, Number of mined P N = 384 15872
# Validation loss:  36.68320053100586
# Total number of batches in train_loader: 781
# Epoch 56 Iteration 0: Loss = 36.4215087890625, Number of mined P N = 384 15872
# Epoch 56 Iteration 100: Loss = 36.33250427246094, Number of mined P N = 384 15872
# Epoch 56 Iteration 200: Loss = 37.02522659301758, Number of mined P N = 384 15872
# Epoch 56 Iteration 300: Loss = 36.678428649902344, Number of mined P N = 384 15872
# Epoch 56 Iteration 400: Loss = 36.6686897277832, Number of mined P N = 384 15872
# Epoch 56 Iteration 500: Loss = 36.96774673461914, Number of mined P N = 384 15872
# Epoch 56 Iteration 600: Loss = 36.91096496582031, Number of mined P N = 384 15872
# Epoch 56 Iteration 700: Loss = 36.74853515625, Number of mined P N = 384 15872
# Validation loss:  36.643818359375
# Total number of batches in train_loader: 781
# Epoch 57 Iteration 0: Loss = 36.875057220458984, Number of mined P N = 384 15872
# Epoch 57 Iteration 100: Loss = 36.38429260253906, Number of mined P N = 384 15872
# Epoch 57 Iteration 200: Loss = 36.407466888427734, Number of mined P N = 384 15872
# Epoch 57 Iteration 300: Loss = 36.23959732055664, Number of mined P N = 384 15872
# Epoch 57 Iteration 400: Loss = 36.78211212158203, Number of mined P N = 384 15872
# Epoch 57 Iteration 500: Loss = 37.120582580566406, Number of mined P N = 384 15872
# Epoch 57 Iteration 600: Loss = 36.412994384765625, Number of mined P N = 384 15872
# Epoch 57 Iteration 700: Loss = 36.553733825683594, Number of mined P N = 384 15872
# Validation loss:  36.718746719360354
# Total number of batches in train_loader: 781
# Epoch 58 Iteration 0: Loss = 36.26361083984375, Number of mined P N = 384 15872
# Epoch 58 Iteration 100: Loss = 36.752784729003906, Number of mined P N = 384 15872
# Epoch 58 Iteration 200: Loss = 36.667903900146484, Number of mined P N = 384 15872
# Epoch 58 Iteration 300: Loss = 36.49139404296875, Number of mined P N = 384 15872
# Epoch 58 Iteration 400: Loss = 36.03065490722656, Number of mined P N = 384 15872
# Epoch 58 Iteration 500: Loss = 36.586395263671875, Number of mined P N = 384 15872
# Epoch 58 Iteration 600: Loss = 36.42121124267578, Number of mined P N = 384 15872
# Epoch 58 Iteration 700: Loss = 36.64659118652344, Number of mined P N = 384 15872
# Validation loss:  36.696292877197266
# Total number of batches in train_loader: 781
# Epoch 59 Iteration 0: Loss = 36.48640823364258, Number of mined P N = 384 15872
# Epoch 59 Iteration 100: Loss = 36.342750549316406, Number of mined P N = 384 15872
# Epoch 59 Iteration 200: Loss = 36.830299377441406, Number of mined P N = 384 15872
# Epoch 59 Iteration 300: Loss = 36.57591247558594, Number of mined P N = 384 15872
# Epoch 59 Iteration 400: Loss = 37.20803451538086, Number of mined P N = 384 15872
# Epoch 59 Iteration 500: Loss = 36.907188415527344, Number of mined P N = 384 15872
# Epoch 59 Iteration 600: Loss = 36.084449768066406, Number of mined P N = 384 15872
# Epoch 59 Iteration 700: Loss = 36.507911682128906, Number of mined P N = 384 15872
# Validation loss:  36.684311370849606
# Total number of batches in train_loader: 781
# Epoch 60 Iteration 0: Loss = 36.42964172363281, Number of mined P N = 384 15872
# Epoch 60 Iteration 100: Loss = 36.171363830566406, Number of mined P N = 384 15872
# Epoch 60 Iteration 200: Loss = 36.43293762207031, Number of mined P N = 384 15872
# Epoch 60 Iteration 300: Loss = 37.309173583984375, Number of mined P N = 384 15872
# Epoch 60 Iteration 400: Loss = 36.60527420043945, Number of mined P N = 384 15872
# Epoch 60 Iteration 500: Loss = 36.546356201171875, Number of mined P N = 384 15872
# Epoch 60 Iteration 600: Loss = 36.80385208129883, Number of mined P N = 384 15872
# Epoch 60 Iteration 700: Loss = 37.1046028137207, Number of mined P N = 384 15872
# Validation loss:  36.67762565612793
# Total number of batches in train_loader: 781
# Epoch 61 Iteration 0: Loss = 36.46444320678711, Number of mined P N = 384 15872
# Epoch 61 Iteration 100: Loss = 36.48948287963867, Number of mined P N = 384 15872
# Epoch 61 Iteration 200: Loss = 36.69477844238281, Number of mined P N = 384 15872
# Epoch 61 Iteration 300: Loss = 36.037757873535156, Number of mined P N = 384 15872
# Epoch 61 Iteration 400: Loss = 36.60587692260742, Number of mined P N = 384 15872
# Epoch 61 Iteration 500: Loss = 36.61442565917969, Number of mined P N = 384 15872
# Epoch 61 Iteration 600: Loss = 36.799400329589844, Number of mined P N = 384 15872
# Epoch 61 Iteration 700: Loss = 36.35317611694336, Number of mined P N = 384 15872
# Validation loss:  36.65993553161621
# Total number of batches in train_loader: 781
# Epoch 62 Iteration 0: Loss = 36.7099494934082, Number of mined P N = 384 15872
# Epoch 62 Iteration 100: Loss = 36.9151611328125, Number of mined P N = 384 15872
# Epoch 62 Iteration 200: Loss = 36.62214660644531, Number of mined P N = 384 15872
# Epoch 62 Iteration 300: Loss = 36.497337341308594, Number of mined P N = 384 15872
# Epoch 62 Iteration 400: Loss = 37.011810302734375, Number of mined P N = 384 15872
# Epoch 62 Iteration 500: Loss = 36.36151123046875, Number of mined P N = 384 15872
# Epoch 62 Iteration 600: Loss = 36.905982971191406, Number of mined P N = 384 15872
# Epoch 62 Iteration 700: Loss = 36.661659240722656, Number of mined P N = 384 15872
# Validation loss:  36.637934875488284
# Total number of batches in train_loader: 781
# Epoch 63 Iteration 0: Loss = 37.1634635925293, Number of mined P N = 384 15872
# ...
# Epoch 78 Iteration 300: Loss = 36.717247009277344, Number of mined P N = 384 15872
# Epoch 78 Iteration 400: Loss = 36.83015060424805, Number of mined P N = 384 15872
# Epoch 78 Iteration 500: Loss = 36.62007141113281, Number of mined P N = 384 15872
# Epoch 78 Iteration 600: Loss = 36.10517883300781, Number of mined P N = 384 15872
# Epoch 78 Iteration 700: Loss = 36.38865661621094, Number of mined P N = 384 15872
# Validation loss:  36.64217552185059
# Total number of batches in train_loader: 781
# Epoch 79 Iteration 0: Loss = 36.50909423828125, Number of mined P N = 384 15872
# Epoch 79 Iteration 100: Loss = 37.10459899902344, Number of mined P N = 384 15872
# Epoch 79 Iteration 200: Loss = 36.47048568725586, Number of mined P N = 384 15872
# Epoch 79 Iteration 300: Loss = 36.482444763183594, Number of mined P N = 384 15872
# Epoch 79 Iteration 400: Loss = 36.86476135253906, Number of mined P N = 384 15872
# Epoch 79 Iteration 500: Loss = 36.724700927734375, Number of mined P N = 384 15872
# Epoch 79 Iteration 600: Loss = 36.6556396484375, Number of mined P N = 384 15872
# Epoch 79 Iteration 700: Loss = 36.81886291503906, Number of mined P N = 384 15872
# Validation loss:  36.66411468505859
# Total number of batches in train_loader: 781
# Epoch 80 Iteration 0: Loss = 36.50244903564453, Number of mined P N = 384 15872
# Epoch 80 Iteration 100: Loss = 36.92118835449219, Number of mined P N = 384 15872
# Epoch 80 Iteration 200: Loss = 36.67643356323242, Number of mined P N = 384 15872
# Epoch 80 Iteration 300: Loss = 36.99156951904297, Number of mined P N = 384 15872
# Epoch 80 Iteration 400: Loss = 36.24644470214844, Number of mined P N = 384 15872
# Epoch 80 Iteration 500: Loss = 36.76297378540039, Number of mined P N = 384 15872
# Epoch 80 Iteration 600: Loss = 37.014122009277344, Number of mined P N = 384 15872
# Epoch 80 Iteration 700: Loss = 36.93061065673828, Number of mined P N = 384 15872
# Validation loss:  36.74829231262207
# Total number of batches in train_loader: 781
# Epoch 81 Iteration 0: Loss = 36.73350143432617, Number of mined P N = 384 15872
# Epoch 81 Iteration 100: Loss = 36.441490173339844, Number of mined P N = 384 15872
# Epoch 81 Iteration 200: Loss = 36.91952896118164, Number of mined P N = 384 15872
# Epoch 81 Iteration 300: Loss = 36.9873046875, Number of mined P N = 384 15872
# Epoch 81 Iteration 400: Loss = 37.0406608581543, Number of mined P N = 384 15872
# Epoch 81 Iteration 500: Loss = 36.68544006347656, Number of mined P N = 384 15872
# Epoch 81 Iteration 600: Loss = 36.60455322265625, Number of mined P N = 384 15872
# Epoch 81 Iteration 700: Loss = 36.44475173950195, Number of mined P N = 384 15872
# Validation loss:  36.65846504211426
# Total number of batches in train_loader: 781
# Epoch 82 Iteration 0: Loss = 36.32867431640625, Number of mined P N = 384 15872
# Epoch 82 Iteration 100: Loss = 36.33652114868164, Number of mined P N = 384 15872
# Epoch 82 Iteration 200: Loss = 36.79222869873047, Number of mined P N = 384 15872
# Epoch 82 Iteration 300: Loss = 37.009666442871094, Number of mined P N = 384 15872
# Epoch 82 Iteration 400: Loss = 36.235130310058594, Number of mined P N = 384 15872
# Epoch 82 Iteration 500: Loss = 36.62036895751953, Number of mined P N = 384 15872
# Epoch 82 Iteration 600: Loss = 37.06632995605469, Number of mined P N = 384 15872
# Epoch 82 Iteration 700: Loss = 37.150081634521484, Number of mined P N = 384 15872
# Validation loss:  36.69966926574707
# Total number of batches in train_loader: 781
# Epoch 83 Iteration 0: Loss = 36.839046478271484, Number of mined P N = 384 15872
# Epoch 83 Iteration 100: Loss = 36.871639251708984, Number of mined P N = 384 15872
# Epoch 83 Iteration 200: Loss = 36.64321517944336, Number of mined P N = 384 15872
# Epoch 83 Iteration 300: Loss = 37.4332389831543, Number of mined P N = 384 15872
# Epoch 83 Iteration 400: Loss = 36.67168426513672, Number of mined P N = 384 15872
# Epoch 83 Iteration 500: Loss = 36.802528381347656, Number of mined P N = 384 15872
# Epoch 83 Iteration 600: Loss = 36.59284591674805, Number of mined P N = 384 15872
# Epoch 83 Iteration 700: Loss = 36.56438064575195, Number of mined P N = 384 15872
# Validation loss:  36.69846504211426
# Total number of batches in train_loader: 781
# Epoch 84 Iteration 0: Loss = 36.94529724121094, Number of mined P N = 384 15872
# Epoch 84 Iteration 100: Loss = 36.20992660522461, Number of mined P N = 384 15872
# Epoch 84 Iteration 200: Loss = 36.91246795654297, Number of mined P N = 384 15872
# Epoch 84 Iteration 300: Loss = 36.60831832885742, Number of mined P N = 384 15872
# Epoch 84 Iteration 400: Loss = 36.75843048095703, Number of mined P N = 384 15872
# Epoch 84 Iteration 500: Loss = 36.7172966003418, Number of mined P N = 384 15872
# Epoch 84 Iteration 600: Loss = 36.259971618652344, Number of mined P N = 384 15872
# Epoch 84 Iteration 700: Loss = 36.82154083251953, Number of mined P N = 384 15872
# Validation loss:  36.67263282775879
# Total number of batches in train_loader: 781
# Epoch 85 Iteration 0: Loss = 36.82961654663086, Number of mined P N = 384 15872
# Epoch 85 Iteration 100: Loss = 36.28941345214844, Number of mined P N = 384 15872
# Epoch 85 Iteration 200: Loss = 36.90088653564453, Number of mined P N = 384 15872
# Epoch 85 Iteration 300: Loss = 36.698875427246094, Number of mined P N = 384 15872
# Epoch 85 Iteration 400: Loss = 36.764312744140625, Number of mined P N = 384 15872
# Epoch 85 Iteration 500: Loss = 36.30974578857422, Number of mined P N = 384 15872
# Epoch 85 Iteration 600: Loss = 36.256046295166016, Number of mined P N = 384 15872
# Epoch 85 Iteration 700: Loss = 36.63896179199219, Number of mined P N = 384 15872
# Validation loss:  36.64306503295899
# Total number of batches in train_loader: 781
# Epoch 86 Iteration 0: Loss = 37.015342712402344, Number of mined P N = 384 15872
# Epoch 86 Iteration 100: Loss = 36.658790588378906, Number of mined P N = 384 15872
# Epoch 86 Iteration 200: Loss = 36.51249313354492, Number of mined P N = 384 15872
# Epoch 86 Iteration 300: Loss = 35.986976623535156, Number of mined P N = 384 15872
# Epoch 86 Iteration 400: Loss = 36.756988525390625, Number of mined P N = 384 15872
# Epoch 86 Iteration 500: Loss = 36.901756286621094, Number of mined P N = 384 15872
# Epoch 86 Iteration 600: Loss = 36.11664581298828, Number of mined P N = 384 15872
# Epoch 86 Iteration 700: Loss = 36.447879791259766, Number of mined P N = 384 15872
# Validation loss:  36.693239517211914
# Total number of batches in train_loader: 781
# Epoch 87 Iteration 0: Loss = 36.44440460205078, Number of mined P N = 384 15872
# Epoch 87 Iteration 100: Loss = 37.243568420410156, Number of mined P N = 384 15872
# Epoch 87 Iteration 200: Loss = 36.592369079589844, Number of mined P N = 384 15872
# Epoch 87 Iteration 300: Loss = 37.35184097290039, Number of mined P N = 384 15872
# Epoch 87 Iteration 400: Loss = 37.161712646484375, Number of mined P N = 384 15872
# Epoch 87 Iteration 500: Loss = 36.442657470703125, Number of mined P N = 384 15872
# Epoch 87 Iteration 600: Loss = 36.3868522644043, Number of mined P N = 384 15872
# Epoch 87 Iteration 700: Loss = 36.51753616333008, Number of mined P N = 384 15872
# Validation loss:  36.646386032104495
# Total number of batches in train_loader: 781
# Epoch 88 Iteration 0: Loss = 36.77773666381836, Number of mined P N = 384 15872
# Epoch 88 Iteration 100: Loss = 36.788761138916016, Number of mined P N = 384 15872
# Epoch 88 Iteration 200: Loss = 36.758148193359375, Number of mined P N = 384 15872
# Epoch 88 Iteration 300: Loss = 36.189300537109375, Number of mined P N = 384 15872
# Epoch 88 Iteration 400: Loss = 36.4375, Number of mined P N = 384 15872
# Epoch 88 Iteration 500: Loss = 36.54700469970703, Number of mined P N = 384 15872
# Epoch 88 Iteration 600: Loss = 36.21146774291992, Number of mined P N = 384 15872
# Epoch 88 Iteration 700: Loss = 36.543739318847656, Number of mined P N = 384 15872
# Validation loss:  36.61939338684082
# Total number of batches in train_loader: 781
# Epoch 89 Iteration 0: Loss = 36.331817626953125, Number of mined P N = 384 15872
# Epoch 89 Iteration 100: Loss = 36.48118591308594, Number of mined P N = 384 15872
# Epoch 89 Iteration 200: Loss = 36.34389114379883, Number of mined P N = 384 15872
# Epoch 89 Iteration 300: Loss = 36.418128967285156, Number of mined P N = 384 15872
# Epoch 89 Iteration 400: Loss = 37.32733917236328, Number of mined P N = 384 15872
# Epoch 89 Iteration 500: Loss = 36.76861572265625, Number of mined P N = 384 15872
# Epoch 89 Iteration 600: Loss = 36.68637466430664, Number of mined P N = 384 15872
# Epoch 89 Iteration 700: Loss = 36.29473876953125, Number of mined P N = 384 15872
# Validation loss:  36.69465385437012
# Total number of batches in train_loader: 781
# Epoch 90 Iteration 0: Loss = 37.05467987060547, Number of mined P N = 384 15872
# Epoch 90 Iteration 100: Loss = 37.753875732421875, Number of mined P N = 384 15872
# Epoch 90 Iteration 200: Loss = 36.56035614013672, Number of mined P N = 384 15872
# Epoch 90 Iteration 300: Loss = 36.69041442871094, Number of mined P N = 384 15872
# Epoch 90 Iteration 400: Loss = 36.03575897216797, Number of mined P N = 384 15872
# Epoch 90 Iteration 500: Loss = 37.04673767089844, Number of mined P N = 384 15872
# Epoch 90 Iteration 600: Loss = 36.688743591308594, Number of mined P N = 384 15872
# Epoch 90 Iteration 700: Loss = 36.59104919433594, Number of mined P N = 384 15872
# Validation loss:  36.67214721679687
# Total number of batches in train_loader: 781
# Epoch 91 Iteration 0: Loss = 36.54387664794922, Number of mined P N = 384 15872
# Epoch 91 Iteration 100: Loss = 36.642234802246094, Number of mined P N = 384 15872
# Epoch 91 Iteration 200: Loss = 36.51078414916992, Number of mined P N = 384 15872
# Epoch 91 Iteration 300: Loss = 36.5263557434082, Number of mined P N = 384 15872
# Epoch 91 Iteration 400: Loss = 36.6375617980957, Number of mined P N = 384 15872
# Epoch 91 Iteration 500: Loss = 36.780853271484375, Number of mined P N = 384 15872
# Epoch 91 Iteration 600: Loss = 37.78221893310547, Number of mined P N = 384 15872
# Epoch 91 Iteration 700: Loss = 36.91667175292969, Number of mined P N = 384 15872
# Validation loss:  36.64452766418457
# Total number of batches in train_loader: 781
# Epoch 92 Iteration 0: Loss = 36.43518829345703, Number of mined P N = 384 15872
# Epoch 92 Iteration 100: Loss = 36.353816986083984, Number of mined P N = 384 15872
# Epoch 92 Iteration 200: Loss = 36.95334243774414, Number of mined P N = 384 15872
# Epoch 92 Iteration 300: Loss = 36.534278869628906, Number of mined P N = 384 15872
# Epoch 92 Iteration 400: Loss = 36.692169189453125, Number of mined P N = 384 15872
# Epoch 92 Iteration 500: Loss = 36.648292541503906, Number of mined P N = 384 15872
# Epoch 92 Iteration 600: Loss = 36.523193359375, Number of mined P N = 384 15872
# Epoch 92 Iteration 700: Loss = 36.57325744628906, Number of mined P N = 384 15872
# Validation loss:  36.7201619720459
# Total number of batches in train_loader: 781
# Epoch 93 Iteration 0: Loss = 36.582801818847656, Number of mined P N = 384 15872
# Epoch 93 Iteration 100: Loss = 36.60588836669922, Number of mined P N = 384 15872
# Epoch 93 Iteration 200: Loss = 36.909786224365234, Number of mined P N = 384 15872
# Epoch 93 Iteration 300: Loss = 37.40040588378906, Number of mined P N = 384 15872
# Epoch 93 Iteration 400: Loss = 36.580223083496094, Number of mined P N = 384 15872
# Epoch 93 Iteration 500: Loss = 37.0263786315918, Number of mined P N = 384 15872
# Epoch 93 Iteration 600: Loss = 36.733680725097656, Number of mined P N = 384 15872
# Epoch 93 Iteration 700: Loss = 37.123748779296875, Number of mined P N = 384 15872
# Validation loss:  36.724496383666995
# Total number of batches in train_loader: 781
# Epoch 94 Iteration 0: Loss = 36.460914611816406, Number of mined P N = 384 15872
# Epoch 94 Iteration 100: Loss = 37.09321594238281, Number of mined P N = 384 15872
# Epoch 94 Iteration 200: Loss = 36.572906494140625, Number of mined P N = 384 15872
# Epoch 94 Iteration 300: Loss = 36.83844757080078, Number of mined P N = 384 15872
# Epoch 94 Iteration 400: Loss = 36.3288459777832, Number of mined P N = 384 15872
# Epoch 94 Iteration 500: Loss = 36.560462951660156, Number of mined P N = 384 15872
# Epoch 94 Iteration 600: Loss = 36.65071105957031, Number of mined P N = 384 15872
# Epoch 94 Iteration 700: Loss = 37.15765380859375, Number of mined P N = 384 15872
# Validation loss:  36.66954986572266
# Total number of batches in train_loader: 781
# Epoch 95 Iteration 0: Loss = 37.173336029052734, Number of mined P N = 384 15872
# Epoch 95 Iteration 100: Loss = 36.798946380615234, Number of mined P N = 384 15872
# Epoch 95 Iteration 200: Loss = 37.08066177368164, Number of mined P N = 384 15872
# Epoch 95 Iteration 300: Loss = 36.5881233215332, Number of mined P N = 384 15872
# Epoch 95 Iteration 400: Loss = 36.510345458984375, Number of mined P N = 384 15872
# Epoch 95 Iteration 500: Loss = 36.875274658203125, Number of mined P N = 384 15872
# Epoch 95 Iteration 600: Loss = 36.486724853515625, Number of mined P N = 384 15872
# Epoch 95 Iteration 700: Loss = 36.875301361083984, Number of mined P N = 384 15872
# Validation loss:  36.73740364074707
# Total number of batches in train_loader: 781
# Epoch 96 Iteration 0: Loss = 36.56353759765625, Number of mined P N = 384 15872
# Epoch 96 Iteration 100: Loss = 36.9592399597168, Number of mined P N = 384 15872
# Epoch 96 Iteration 200: Loss = 37.179569244384766, Number of mined P N = 384 15872
# Epoch 96 Iteration 300: Loss = 36.589149475097656, Number of mined P N = 384 15872
# Epoch 96 Iteration 400: Loss = 36.466033935546875, Number of mined P N = 384 15872
# Epoch 96 Iteration 500: Loss = 36.845462799072266, Number of mined P N = 384 15872
# Epoch 96 Iteration 600: Loss = 36.84848403930664, Number of mined P N = 384 15872
# Epoch 96 Iteration 700: Loss = 36.18284606933594, Number of mined P N = 384 15872
# Validation loss:  36.68356597900391
# Total number of batches in train_loader: 781
# Epoch 97 Iteration 0: Loss = 37.19778823852539, Number of mined P N = 384 15872
# Epoch 97 Iteration 100: Loss = 37.36134338378906, Number of mined P N = 384 15872
# Epoch 97 Iteration 200: Loss = 36.398948669433594, Number of mined P N = 384 15872
# Epoch 97 Iteration 300: Loss = 36.70826721191406, Number of mined P N = 384 15872
# Epoch 97 Iteration 400: Loss = 37.39739990234375, Number of mined P N = 384 15872
# Epoch 97 Iteration 500: Loss = 36.87110900878906, Number of mined P N = 384 15872
# Epoch 97 Iteration 600: Loss = 36.92420959472656, Number of mined P N = 384 15872
# Epoch 97 Iteration 700: Loss = 37.18353271484375, Number of mined P N = 384 15872
# Validation loss:  36.72648315429687
# Total number of batches in train_loader: 781
# Epoch 98 Iteration 0: Loss = 36.87680435180664, Number of mined P N = 384 15872
# Epoch 98 Iteration 100: Loss = 36.333717346191406, Number of mined P N = 384 15872
# Epoch 98 Iteration 200: Loss = 36.253108978271484, Number of mined P N = 384 15872
# Epoch 98 Iteration 300: Loss = 36.5059814453125, Number of mined P N = 384 15872
# Epoch 98 Iteration 400: Loss = 36.83854675292969, Number of mined P N = 384 15872
# Epoch 98 Iteration 500: Loss = 36.30320739746094, Number of mined P N = 384 15872
# Epoch 98 Iteration 600: Loss = 37.015689849853516, Number of mined P N = 384 15872
# Epoch 98 Iteration 700: Loss = 36.67511749267578, Number of mined P N = 384 15872
# Validation loss:  36.67945068359375
# Total number of batches in train_loader: 781
# Epoch 99 Iteration 0: Loss = 36.33740997314453, Number of mined P N = 384 15872
# Epoch 99 Iteration 100: Loss = 36.51815414428711, Number of mined P N = 384 15872
# Epoch 99 Iteration 200: Loss = 36.913429260253906, Number of mined P N = 384 15872
# Epoch 99 Iteration 300: Loss = 36.52163314819336, Number of mined P N = 384 15872
# Epoch 99 Iteration 400: Loss = 36.695579528808594, Number of mined P N = 384 15872
# Epoch 99 Iteration 500: Loss = 36.57331085205078, Number of mined P N = 384 15872
# Epoch 99 Iteration 600: Loss = 36.75700378417969, Number of mined P N = 384 15872
# Epoch 99 Iteration 700: Loss = 36.671531677246094, Number of mined P N = 384 15872
# Validation loss:  36.68617042541504
